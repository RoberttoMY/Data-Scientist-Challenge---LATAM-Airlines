# %% [markdown]
# # Importando librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math as m
from datetime import datetime

import scipy.stats as st
from scipy.stats import t as t_student
from scipy.stats import norm

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols
from statsmodels.stats import anova
from statsmodels.stats.anova import anova_lm

from statsmodels.graphics.factorplots import interaction_plot
from  statsmodels.stats.multicomp import pairwise_tukeyhsd

# %% [markdown]
# # Cargando data set

# %%
df=pd.read_csv('dataset_SCL.csv')
df
# Out:
# C:\Users\Roberto\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                    Fecha-I Vlo-I Ori-I Des-I Emp-I              Fecha-O  \
# 0      2017-01-01 23:30:00   226  SCEL  KMIA   AAL  2017-01-01 23:33:00
# 1      2017-01-02 23:30:00   226  SCEL  KMIA   AAL  2017-01-02 23:39:00
# 2      2017-01-03 23:30:00   226  SCEL  KMIA   AAL  2017-01-03 23:39:00
# 3      2017-01-04 23:30:00   226  SCEL  KMIA   AAL  2017-01-04 23:33:00
# 4      2017-01-05 23:30:00   226  SCEL  KMIA   AAL  2017-01-05 23:28:00
# ...                    ...   ...   ...   ...   ...                  ...
# 68201  2017-12-22 14:55:00   400  SCEL  SPJC   JAT  2017-12-22 15:41:00
# 68202  2017-12-25 14:55:00   400  SCEL  SPJC   JAT  2017-12-25 15:11:00
# 68203  2017-12-27 14:55:00   400  SCEL  SPJC   JAT  2017-12-27 15:35:00
# 68204  2017-12-29 14:55:00   400  SCEL  SPJC   JAT  2017-12-29 15:08:00
# 68205  2017-12-31 14:55:00   400  SCEL  SPJC   JAT  2017-12-31 15:04:00
#
#        Vlo-O Ori-O Des-O Emp-O  DIA  MES   AÑO     DIANOM TIPOVUELO  \
# 0        226  SCEL  KMIA   AAL    1    1  2017    Domingo         I
# 1        226  SCEL  KMIA   AAL    2    1  2017      Lunes         I
# 2        226  SCEL  KMIA   AAL    3    1  2017     Martes         I
# 3        226  SCEL  KMIA   AAL    4    1  2017  Miercoles         I
# 4        226  SCEL  KMIA   AAL    5    1  2017     Jueves         I
# ...      ...   ...   ...   ...  ...  ...   ...        ...       ...
# 68201  400.0  SCEL  SPJC   JAT   22   12  2017    Viernes         I
# 68202  400.0  SCEL  SPJC   JAT   25   12  2017      Lunes         I
# 68203  400.0  SCEL  SPJC   JAT   27   12  2017  Miercoles         I
# 68204  400.0  SCEL  SPJC   JAT   29   12  2017    Viernes         I
# 68205  400.0  SCEL  SPJC   JAT   31   12  2017    Domingo         I
#
#                    OPERA  SIGLAORI SIGLADES
# 0      American Airlines  Santiago    Miami
# 1      American Airlines  Santiago    Miami
# 2      American Airlines  Santiago    Miami
# 3      American Airlines  Santiago    Miami
# 4      American Airlines  Santiago    Miami
# ...                  ...       ...      ...
# 68201       JetSmart SPA  Santiago     Lima
# 68202       JetSmart SPA  Santiago     Lima
# 68203       JetSmart SPA  Santiago     Lima
# 68204       JetSmart SPA  Santiago     Lima
# 68205       JetSmart SPA  Santiago     Lima
#
# [68206 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68206 entries, 0 to 68205
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha-I    68206 non-null  object
#  1   Vlo-I      68206 non-null  object
#  2   Ori-I      68206 non-null  object
#  3   Des-I      68206 non-null  object
#  4   Emp-I      68206 non-null  object
#  5   Fecha-O    68206 non-null  object
#  6   Vlo-O      68205 non-null  object
#  7   Ori-O      68206 non-null  object
#  8   Des-O      68206 non-null  object
#  9   Emp-O      68206 non-null  object
#  10  DIA        68206 non-null  int64
#  11  MES        68206 non-null  int64
#  12  AÑO        68206 non-null  int64
#  13  DIANOM     68206 non-null  object
#  14  TIPOVUELO  68206 non-null  object
#  15  OPERA      68206 non-null  object
#  16  SIGLAORI   68206 non-null  object
#  17  SIGLADES   68206 non-null  object
# dtypes: int64(3), object(15)
# memory usage: 9.4+ MB

# %% [markdown]
# # 1.
# # ¿Cómo se distribuyen los datos? ¿Qué te llama la atención o cuál es tu conclusión sobre esto?

# %% [markdown]
# ### Respuesta
#
# Los datos se distribuyen de diferente manera

# %% [markdown]
# ### Analisis

# %%
plt.figure(figsize=(15,10))
plot = df['Emp-I'].value_counts().plot(kind='bar',title='Cantidad Vuelos Programados Aerolineas')

# %% [raw]
# plt.figure(figsize=(20,10))
# sns.histplot(df['Emp-I'],kde=True)
# plt.title('Cantidad Vuelos Programados Aerolineas',fontsize=25)

# %%
df['Emp-I'].describe()
# Out:
# count     68206
# unique       30
# top         LAN
# freq      37611
# Name: Emp-I, dtype: object

# %%
pd.value_counts(df['Emp-I'])
# Out:
# LAN    37611
# SKU    14298
# TAM     3049
# ARG     1949
# CMP     1850
# LAW     1574
# AVA     1152
# JAT     1095
# GLO      806
# AAL      757
# ACA      565
# IBE      362
# DAL      358
# AFR      358
# AMX      351
# UAL      335
# ONE      279
# AZA      259
# KLM      251
# LAP      216
# BAW      205
# QFU      195
# JMR      100
# LRC       92
# AUT       74
# PUE       49
# LXP        9
# LPE        4
# DSM        2
# LNE        1
# Name: Emp-I, dtype: int64

# %%
df['Emp-I'][df['Emp-I']=='LAN'].count()
# Out:
# 37611

# %%
plt.figure(figsize=(15,10))
plot = df['Emp-O'].value_counts().plot(kind='bar',title='Cantidad Vuelos Operados Aerolineas')

# %%
df['Emp-O'].describe()
# Out:
# count     68206
# unique       32
# top         LAN
# freq      20988
# Name: Emp-O, dtype: object

# %%
pd.value_counts(df['Emp-O'])
# Out:
# LAN    20988
# LXP    14558
# SKU    14298
# TAM     3046
# ARG     1946
# CMP     1850
# JMR     1647
# LPE     1214
# JAT     1095
# AVA      885
# GLO      806
# AAL      757
# ACA      565
# DSM      493
# LNE      374
# IBE      362
# DAL      358
# AFR      358
# LRC      357
# AMX      351
# UAL      335
# ONE      279
# AZA      259
# KLM      251
# LAP      219
# BAW      205
# QFA      195
# AUT       77
# PUE       49
# 56R       17
# 48O       10
# TPU        2
# Name: Emp-O, dtype: int64

# %%
plt.figure(figsize=(15,10))
plot = df['Ori-I'].value_counts().plot(kind='bar',title='Cantidad Vuelos Programados Ciudades Origen')

# %%
df['Ori-I'].describe()
# Out:
# count     68206
# unique        1
# top        SCEL
# freq      68206
# Name: Ori-I, dtype: object

# %%
pd.value_counts(df['Ori-I'])
# Out:
# SCEL    68206
# Name: Ori-I, dtype: int64

# %%
plt.figure(figsize=(15,10))
plot = df['Ori-O'].value_counts().plot(kind='bar',title='Cantidad Vuelos Operados Ciudades Origen')

# %%
df['Ori-O'].describe()
# Out:
# count     68206
# unique        1
# top        SCEL
# freq      68206
# Name: Ori-O, dtype: object

# %%
pd.value_counts(df['Ori-O'])
# Out:
# SCEL    68206
# Name: Ori-O, dtype: int64

# %%
plt.figure(figsize=(15,10))
plot = df['Des-I'].value_counts().plot(kind='bar',title='Cantidad Vuelos Programados Ciudades Destino')

# %%
df['Des-I'].describe()
# Out:
# count     68206
# unique       64
# top        SCFA
# freq       5787
# Name: Des-I, dtype: object

# %%
pd.value_counts(df['Des-I'])
# Out:
# SCFA    5787
# SPJC    5270
# SCCF    5145
# SCTE    4357
# SCIE    3995
#         ...
# SLCB       1
# SEQM       1
# SARI       1
# SPSO       1
# EGYP       1
# Name: Des-I, Length: 64, dtype: int64

# %%
plt.figure(figsize=(15,10))
plot = df['Des-O'].value_counts().plot(kind='bar',title='Cantidad Vuelos Operacion Ciudades Destino')

# %%
df['Des-O'].describe()
# Out:
# count     68206
# unique       63
# top        SCFA
# freq       5786
# Name: Des-O, dtype: object

# %%
pd.value_counts(df['Des-O'])
# Out:
# SCFA    5786
# SPJC    5270
# SCCF    5146
# SCTE    4357
# SCIE    3993
#         ...
# SBFI       2
# KIAD       1
# SLCB       1
# EGYP       1
# SPSO       1
# Name: Des-O, Length: 63, dtype: int64

# %%
plt.figure(figsize=(15,10))
plot = df['DIA'].value_counts(sort=False).plot(kind='bar',title='Dias Vuelos')

# %%
df['DIA'].describe()
# Out:
# count    68206.000000
# mean        15.714790
# std          8.782886
# min          1.000000
# 25%          8.000000
# 50%         16.000000
# 75%         23.000000
# max         31.000000
# Name: DIA, dtype: float64

# %%
pd.value_counts(df['DIA'],sort=False)
# Out:
# 1     2208
# 2     2223
# 3     2271
# 4     2215
# 5     2241
# 6     2275
# 7     2264
# 8     2213
# 9     2227
# 10    2283
# 11    2237
# 12    2284
# 13    2272
# 14    2221
# 15    2239
# 16    2268
# 17    2228
# 18    2160
# 19    2238
# 20    2290
# 21    2267
# 22    2272
# 23    2260
# 24    2232
# 25    2179
# 26    2267
# 27    2286
# 28    2232
# 29    2044
# 30    2020
# 31    1290
# Name: DIA, dtype: int64

# %%
plt.figure(figsize=(15,10))
plot = df['MES'].value_counts(sort=False).plot(kind='bar',title='Meses Vuelos')

# %%
df['MES'].describe()
# Out:
# count    68206.000000
# mean         6.622585
# std          3.523321
# min          1.000000
# 25%          3.000000
# 50%          7.000000
# 75%         10.000000
# max         12.000000
# Name: MES, dtype: float64

# %%
pd.value_counts(df['MES'],sort=True)
# Out:
# 12    6356
# 1     6108
# 11    6080
# 10    6032
# 7     5992
# 8     5744
# 9     5610
# 2     5561
# 3     5482
# 5     5240
# 4     5020
# 6     4981
# Name: MES, dtype: int64

# %%
plt.figure(figsize=(15,10))
plot = df['AÑO'].value_counts().plot(kind='bar',title='Años Vuelos')

# %%
df['AÑO'].describe()
# Out:
# count    68206.000000
# mean      2017.000029
# std          0.005415
# min       2017.000000
# 25%       2017.000000
# 50%       2017.000000
# 75%       2017.000000
# max       2018.000000
# Name: AÑO, dtype: float64

# %%
pd.value_counts(df['AÑO'])
# Out:
# 2017    68204
# 2018        2
# Name: AÑO, dtype: int64

# %%
plt.figure(figsize=(15,10))
plot = df['DIANOM'].value_counts().plot(kind='bar',title='Dias Semana Vuelos')

# %%
df['DIANOM'].describe()
# Out:
# count       68206
# unique          7
# top       Viernes
# freq        10292
# Name: DIANOM, dtype: object

# %%
pd.value_counts(df['DIANOM'])
# Out:
# Viernes      10292
# Jueves       10251
# Lunes        10131
# Domingo       9796
# Miercoles     9722
# Martes        9662
# Sabado        8352
# Name: DIANOM, dtype: int64

# %%
plt.figure(figsize=(15,10))
plot = df['TIPOVUELO'].value_counts().plot(kind='bar',title='Vuelos Tipo Vuelo')

# %%
df['TIPOVUELO'].describe()
# Out:
# count     68206
# unique        2
# top           N
# freq      36966
# Name: TIPOVUELO, dtype: object

# %%
pd.value_counts(df['TIPOVUELO'])
# Out:
# N    36966
# I    31240
# Name: TIPOVUELO, dtype: int64

# %%
plt.figure(figsize=(15,10))
plot = df['OPERA'].value_counts().plot(kind='bar',title='Aerolineas Vuelos')

# %%
df['OPERA'].describe()
# Out:
# count           68206
# unique             23
# top       Grupo LATAM
# freq            40892
# Name: OPERA, dtype: object

# %%
pd.value_counts(df['OPERA'])
# Out:
# Grupo LATAM                 40892
# Sky Airline                 14298
# Aerolineas Argentinas        1949
# Copa Air                     1850
# Latin American Wings         1674
# Avianca                      1152
# JetSmart SPA                 1095
# Gol Trans                     806
# American Airlines             757
# Air Canada                    565
# Iberia                        362
# Delta Air                     358
# Air France                    358
# Aeromexico                    351
# United Airlines               335
# Oceanair Linhas Aereas        279
# Alitalia                      259
# K.L.M.                        251
# British Airways               205
# Qantas Airways                195
# Lacsa                          92
# Austral                        74
# Plus Ultra Lineas Aereas       49
# Name: OPERA, dtype: int64

# %%
plt.figure(figsize=(15,10))
plot = df['SIGLAORI'].value_counts().plot(kind='bar',title='Ciudad Origen Vuelos')

# %%
df['SIGLAORI'].describe()
# Out:
# count        68206
# unique           1
# top       Santiago
# freq         68206
# Name: SIGLAORI, dtype: object

# %%
pd.value_counts(df['SIGLAORI'])
# Out:
# Santiago    68206
# Name: SIGLAORI, dtype: int64

# %%
plt.figure(figsize=(15,10))
plot = df['SIGLADES'].value_counts().plot(kind='bar',title='Nombre Ciudad Destino Vuelos')

# %%
df['SIGLADES'].describe()
# Out:
# count            68206
# unique              62
# top       Buenos Aires
# freq              6335
# Name: SIGLADES, dtype: object

# %%
pd.value_counts(df['SIGLADES'])
# Out:
# Buenos Aires      6335
# Antofagasta       5786
# Lima              5270
# Calama            5146
# Puerto Montt      4357
#                   ...
# Quito                2
# Pisco, Peru          1
# Washington           1
# Cochabamba           1
# Puerto Stanley       1
# Name: SIGLADES, Length: 62, dtype: int64

# %%
sns.pairplot(df)

# %% [markdown]
# # 2.
# # Genera las columnas adicionales y luego expórtelas en un archivo synthetic_features.csv

# %%
df['Fecha-I']=pd.to_datetime(df['Fecha-I'])
df['Fecha-O']=pd.to_datetime(df['Fecha-O'])
df.dtypes
# Out:
# Fecha-I      datetime64[ns]
# Vlo-I                object
# Ori-I                object
# Des-I                object
# Emp-I                object
# Fecha-O      datetime64[ns]
# Vlo-O                object
# Ori-O                object
# Des-O                object
# Emp-O                object
# DIA                   int64
# MES                   int64
# AÑO                   int64
# DIANOM               object
# TIPOVUELO            object
# OPERA                object
# SIGLAORI             object
# SIGLADES             object
# dtype: object

# %%
df[(df['Fecha-I']>='2017-12-15') | (df['Fecha-I']<='2017-03-03')]
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O  Vlo-O  \
# 0     2017-01-01 23:30:00   226  SCEL  KMIA   AAL 2017-01-01 23:33:00    226
# 1     2017-01-02 23:30:00   226  SCEL  KMIA   AAL 2017-01-02 23:39:00    226
# 2     2017-01-03 23:30:00   226  SCEL  KMIA   AAL 2017-01-03 23:39:00    226
# 3     2017-01-04 23:30:00   226  SCEL  KMIA   AAL 2017-01-04 23:33:00    226
# 4     2017-01-05 23:30:00   226  SCEL  KMIA   AAL 2017-01-05 23:28:00    226
# ...                   ...   ...   ...   ...   ...                 ...    ...
# 68201 2017-12-22 14:55:00   400  SCEL  SPJC   JAT 2017-12-22 15:41:00  400.0
# 68202 2017-12-25 14:55:00   400  SCEL  SPJC   JAT 2017-12-25 15:11:00  400.0
# 68203 2017-12-27 14:55:00   400  SCEL  SPJC   JAT 2017-12-27 15:35:00  400.0
# 68204 2017-12-29 14:55:00   400  SCEL  SPJC   JAT 2017-12-29 15:08:00  400.0
# 68205 2017-12-31 14:55:00   400  SCEL  SPJC   JAT 2017-12-31 15:04:00  400.0
#
#       Ori-O Des-O Emp-O  DIA  MES   AÑO     DIANOM TIPOVUELO  \
# 0      SCEL  KMIA   AAL    1    1  2017    Domingo         I
# 1      SCEL  KMIA   AAL    2    1  2017      Lunes         I
# 2      SCEL  KMIA   AAL    3    1  2017     Martes         I
# 3      SCEL  KMIA   AAL    4    1  2017  Miercoles         I
# 4      SCEL  KMIA   AAL    5    1  2017     Jueves         I
# ...     ...   ...   ...  ...  ...   ...        ...       ...
# 68201  SCEL  SPJC   JAT   22   12  2017    Viernes         I
# 68202  SCEL  SPJC   JAT   25   12  2017      Lunes         I
# 68203  SCEL  SPJC   JAT   27   12  2017  Miercoles         I
# 68204  SCEL  SPJC   JAT   29   12  2017    Viernes         I
# 68205  SCEL  SPJC   JAT   31   12  2017    Domingo         I
#
#                    OPERA  SIGLAORI SIGLADES
# 0      American Airlines  Santiago    Miami
# 1      American Airlines  Santiago    Miami
# 2      American Airlines  Santiago    Miami
# 3      American Airlines  Santiago    Miami
# 4      American Airlines  Santiago    Miami
# ...                  ...       ...      ...
# 68201       JetSmart SPA  Santiago     Lima
# 68202       JetSmart SPA  Santiago     Lima
# 68203       JetSmart SPA  Santiago     Lima
# 68204       JetSmart SPA  Santiago     Lima
# 68205       JetSmart SPA  Santiago     Lima
#
# [15525 rows x 18 columns]

# %%
df[(df['Fecha-I']>='2017-07-15') & (df['Fecha-I']<='2017-07-31')]
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O Vlo-O  \
# 32405 2017-07-15 20:00:00   912  SCEL  KMIA   AAL 2017-07-15 21:59:00   912
# 32406 2017-07-17 20:00:00   912  SCEL  KMIA   AAL 2017-07-17 20:00:00   912
# 32407 2017-07-18 20:00:00   912  SCEL  KMIA   AAL 2017-07-18 20:03:00   912
# 32408 2017-07-19 20:00:00   912  SCEL  KMIA   AAL 2017-07-19 19:51:00   912
# 32409 2017-07-20 20:00:00   912  SCEL  KMIA   AAL 2017-07-20 19:56:00   912
# ...                   ...   ...   ...   ...   ...                 ...   ...
# 38376 2017-07-26 18:47:00     8  SCEL  SCCF   JAT 2017-07-26 19:03:00     8
# 38377 2017-07-27 18:47:00     8  SCEL  SCCF   JAT 2017-07-27 18:57:00     8
# 38378 2017-07-28 18:47:00     8  SCEL  SCCF   JAT 2017-07-28 18:50:00     8
# 38379 2017-07-30 18:47:00     8  SCEL  SCCF   JAT 2017-07-30 18:55:00     8
# 38381 2017-07-24 09:30:00    22  SCEL  SCCF   JAT 2017-07-24 09:40:00    22
#
#       Ori-O Des-O Emp-O  DIA  MES   AÑO     DIANOM TIPOVUELO  \
# 32405  SCEL  KMIA   AAL   15    7  2017     Sabado         I
# 32406  SCEL  KMIA   AAL   17    7  2017      Lunes         I
# 32407  SCEL  KMIA   AAL   18    7  2017     Martes         I
# 32408  SCEL  KMIA   AAL   19    7  2017  Miercoles         I
# 32409  SCEL  KMIA   AAL   20    7  2017     Jueves         I
# ...     ...   ...   ...  ...  ...   ...        ...       ...
# 38376  SCEL  SCCF   JAT   26    7  2017  Miercoles         N
# 38377  SCEL  SCCF   JAT   27    7  2017     Jueves         N
# 38378  SCEL  SCCF   JAT   28    7  2017    Viernes         N
# 38379  SCEL  SCCF   JAT   30    7  2017    Domingo         N
# 38381  SCEL  SCCF   JAT   24    7  2017      Lunes         N
#
#                    OPERA  SIGLAORI SIGLADES
# 32405  American Airlines  Santiago    Miami
# 32406  American Airlines  Santiago    Miami
# 32407  American Airlines  Santiago    Miami
# 32408  American Airlines  Santiago    Miami
# 32409  American Airlines  Santiago    Miami
# ...                  ...       ...      ...
# 38376       JetSmart SPA  Santiago   Calama
# 38377       JetSmart SPA  Santiago   Calama
# 38378       JetSmart SPA  Santiago   Calama
# 38379       JetSmart SPA  Santiago   Calama
# 38381       JetSmart SPA  Santiago   Calama
#
# [3089 rows x 18 columns]

# %%
df[(df['Fecha-I']>='2017-09-11') & (df['Fecha-I']<='2017-09-30')]
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O Vlo-O  \
# 44132 2017-09-16 21:00:00   912  SCEL  KMIA   AAL 2017-09-16 21:02:00   912
# 44133 2017-09-17 21:00:00   912  SCEL  KMIA   AAL 2017-09-17 21:02:00   912
# 44134 2017-09-18 21:00:00   912  SCEL  KMIA   AAL 2017-09-18 20:55:00   912
# 44135 2017-09-19 21:00:00   912  SCEL  KMIA   AAL 2017-09-19 21:01:00   912
# 44136 2017-09-20 21:00:00   912  SCEL  KMIA   AAL 2017-09-20 20:58:00   912
# ...                   ...   ...   ...   ...   ...                 ...   ...
# 49731 2017-09-29 17:37:00   253  SCEL  SCTE   JAT 2017-09-29 18:02:00   253
# 49732 2017-09-25 13:21:00   281  SCEL  SCQP   JAT 2017-09-25 13:18:00   281
# 49733 2017-09-26 13:21:00   281  SCEL  SCQP   JAT 2017-09-26 13:12:00   281
# 49734 2017-09-27 13:00:00   281  SCEL  SCQP   JAT 2017-09-27 13:02:00   281
# 49735 2017-09-28 12:50:00   281  SCEL  SCQP   JAT 2017-09-28 12:44:00   281
#
#       Ori-O Des-O Emp-O  DIA  MES   AÑO     DIANOM TIPOVUELO  \
# 44132  SCEL  KMIA   AAL   16    9  2017     Sabado         I
# 44133  SCEL  KMIA   AAL   17    9  2017    Domingo         I
# 44134  SCEL  KMIA   AAL   18    9  2017      Lunes         I
# 44135  SCEL  KMIA   AAL   19    9  2017     Martes         I
# 44136  SCEL  KMIA   AAL   20    9  2017  Miercoles         I
# ...     ...   ...   ...  ...  ...   ...        ...       ...
# 49731  SCEL  SCTE   JAT   29    9  2017    Viernes         N
# 49732  SCEL  SCQP   JAT   25    9  2017      Lunes         N
# 49733  SCEL  SCQP   JAT   26    9  2017     Martes         N
# 49734  SCEL  SCQP   JAT   27    9  2017  Miercoles         N
# 49735  SCEL  SCQP   JAT   28    9  2017     Jueves         N
#
#                    OPERA  SIGLAORI      SIGLADES
# 44132  American Airlines  Santiago         Miami
# 44133  American Airlines  Santiago         Miami
# 44134  American Airlines  Santiago         Miami
# 44135  American Airlines  Santiago         Miami
# 44136  American Airlines  Santiago         Miami
# ...                  ...       ...           ...
# 49731       JetSmart SPA  Santiago  Puerto Montt
# 49732       JetSmart SPA  Santiago        Temuco
# 49733       JetSmart SPA  Santiago        Temuco
# 49734       JetSmart SPA  Santiago        Temuco
# 49735       JetSmart SPA  Santiago        Temuco
#
# [3597 rows x 18 columns]

# %%
df[(df['Fecha-I']>='2017-12-15') | (df['Fecha-I']<='2017-03-03') | ((df['Fecha-I']>='2017-07-15') & (df['Fecha-I']<='2017-07-31')) | ((df['Fecha-I']>='2017-09-11') & (df['Fecha-I']<='2017-09-30'))]
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O  Vlo-O  \
# 0     2017-01-01 23:30:00   226  SCEL  KMIA   AAL 2017-01-01 23:33:00    226
# 1     2017-01-02 23:30:00   226  SCEL  KMIA   AAL 2017-01-02 23:39:00    226
# 2     2017-01-03 23:30:00   226  SCEL  KMIA   AAL 2017-01-03 23:39:00    226
# 3     2017-01-04 23:30:00   226  SCEL  KMIA   AAL 2017-01-04 23:33:00    226
# 4     2017-01-05 23:30:00   226  SCEL  KMIA   AAL 2017-01-05 23:28:00    226
# ...                   ...   ...   ...   ...   ...                 ...    ...
# 68201 2017-12-22 14:55:00   400  SCEL  SPJC   JAT 2017-12-22 15:41:00  400.0
# 68202 2017-12-25 14:55:00   400  SCEL  SPJC   JAT 2017-12-25 15:11:00  400.0
# 68203 2017-12-27 14:55:00   400  SCEL  SPJC   JAT 2017-12-27 15:35:00  400.0
# 68204 2017-12-29 14:55:00   400  SCEL  SPJC   JAT 2017-12-29 15:08:00  400.0
# 68205 2017-12-31 14:55:00   400  SCEL  SPJC   JAT 2017-12-31 15:04:00  400.0
#
#       Ori-O Des-O Emp-O  DIA  MES   AÑO     DIANOM TIPOVUELO  \
# 0      SCEL  KMIA   AAL    1    1  2017    Domingo         I
# 1      SCEL  KMIA   AAL    2    1  2017      Lunes         I
# 2      SCEL  KMIA   AAL    3    1  2017     Martes         I
# 3      SCEL  KMIA   AAL    4    1  2017  Miercoles         I
# 4      SCEL  KMIA   AAL    5    1  2017     Jueves         I
# ...     ...   ...   ...  ...  ...   ...        ...       ...
# 68201  SCEL  SPJC   JAT   22   12  2017    Viernes         I
# 68202  SCEL  SPJC   JAT   25   12  2017      Lunes         I
# 68203  SCEL  SPJC   JAT   27   12  2017  Miercoles         I
# 68204  SCEL  SPJC   JAT   29   12  2017    Viernes         I
# 68205  SCEL  SPJC   JAT   31   12  2017    Domingo         I
#
#                    OPERA  SIGLAORI SIGLADES
# 0      American Airlines  Santiago    Miami
# 1      American Airlines  Santiago    Miami
# 2      American Airlines  Santiago    Miami
# 3      American Airlines  Santiago    Miami
# 4      American Airlines  Santiago    Miami
# ...                  ...       ...      ...
# 68201       JetSmart SPA  Santiago     Lima
# 68202       JetSmart SPA  Santiago     Lima
# 68203       JetSmart SPA  Santiago     Lima
# 68204       JetSmart SPA  Santiago     Lima
# 68205       JetSmart SPA  Santiago     Lima
#
# [22211 rows x 18 columns]

# %%
df[(df['Fecha-I'].dt.hour>=5)&(df['Fecha-I'].dt.hour<12)]
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O  Vlo-O  \
# 201   2017-01-01 10:35:00  1281  SCEL  SABE   ARG 2017-01-01 10:25:00   1281
# 202   2017-01-02 10:35:00  1281  SCEL  SABE   ARG 2017-01-02 10:37:00   1281
# 203   2017-01-03 10:35:00  1281  SCEL  SABE   ARG 2017-01-03 10:33:00   1281
# 204   2017-01-04 10:35:00  1281  SCEL  SABE   ARG 2017-01-04 11:06:00   1281
# 205   2017-01-05 10:35:00  1281  SCEL  SABE   ARG 2017-01-05 10:53:00   1281
# ...                   ...   ...   ...   ...   ...                 ...    ...
# 68168 2017-12-15 08:55:00   281  SCEL  SCQP   JAT 2017-12-15 08:56:00  281.0
# 68171 2017-12-20 11:57:00   281  SCEL  SCQP   JAT 2017-12-20 12:02:00  281.0
# 68173 2017-12-22 08:55:00   281  SCEL  SCQP   JAT 2017-12-22 09:01:00  281.0
# 68177 2017-12-27 11:57:00   281  SCEL  SCQP   JAT 2017-12-27 11:58:00  281.0
# 68179 2017-12-29 08:55:00   281  SCEL  SCQP   JAT 2017-12-29 08:49:00  281.0
#
#       Ori-O Des-O Emp-O  DIA  MES   AÑO     DIANOM TIPOVUELO  \
# 201    SCEL  SABE   ARG    1    1  2017    Domingo         I
# 202    SCEL  SABE   ARG    2    1  2017      Lunes         I
# 203    SCEL  SABE   ARG    3    1  2017     Martes         I
# 204    SCEL  SABE   ARG    4    1  2017  Miercoles         I
# 205    SCEL  SABE   ARG    5    1  2017     Jueves         I
# ...     ...   ...   ...  ...  ...   ...        ...       ...
# 68168  SCEL  SCQP   JAT   15   12  2017    Viernes         N
# 68171  SCEL  SCQP   JAT   20   12  2017  Miercoles         N
# 68173  SCEL  SCQP   JAT   22   12  2017    Viernes         N
# 68177  SCEL  SCQP   JAT   27   12  2017  Miercoles         N
# 68179  SCEL  SCQP   JAT   29   12  2017    Viernes         N
#
#                        OPERA  SIGLAORI      SIGLADES
# 201    Aerolineas Argentinas  Santiago  Buenos Aires
# 202    Aerolineas Argentinas  Santiago  Buenos Aires
# 203    Aerolineas Argentinas  Santiago  Buenos Aires
# 204    Aerolineas Argentinas  Santiago  Buenos Aires
# 205    Aerolineas Argentinas  Santiago  Buenos Aires
# ...                      ...       ...           ...
# 68168           JetSmart SPA  Santiago        Temuco
# 68171           JetSmart SPA  Santiago        Temuco
# 68173           JetSmart SPA  Santiago        Temuco
# 68177           JetSmart SPA  Santiago        Temuco
# 68179           JetSmart SPA  Santiago        Temuco
#
# [25352 rows x 18 columns]

# %%
df[(df['Fecha-I'].dt.hour>=12)&(df['Fecha-I'].dt.hour<19)]
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O  Vlo-O  \
# 79    2017-01-01 13:35:00    92  SCEL  SAEZ   ACA 2017-01-01 13:54:00     92
# 80    2017-01-02 13:35:00    92  SCEL  SAEZ   ACA 2017-01-02 14:35:00     92
# 81    2017-01-03 13:35:00    92  SCEL  SAEZ   ACA 2017-01-03 13:52:00     92
# 82    2017-01-04 13:35:00    92  SCEL  SAEZ   ACA 2017-01-04 14:01:00     92
# 83    2017-01-05 13:35:00    92  SCEL  SAEZ   ACA 2017-01-05 13:49:00     92
# ...                   ...   ...   ...   ...   ...                 ...    ...
# 68201 2017-12-22 14:55:00   400  SCEL  SPJC   JAT 2017-12-22 15:41:00  400.0
# 68202 2017-12-25 14:55:00   400  SCEL  SPJC   JAT 2017-12-25 15:11:00  400.0
# 68203 2017-12-27 14:55:00   400  SCEL  SPJC   JAT 2017-12-27 15:35:00  400.0
# 68204 2017-12-29 14:55:00   400  SCEL  SPJC   JAT 2017-12-29 15:08:00  400.0
# 68205 2017-12-31 14:55:00   400  SCEL  SPJC   JAT 2017-12-31 15:04:00  400.0
#
#       Ori-O Des-O Emp-O  DIA  MES   AÑO     DIANOM TIPOVUELO         OPERA  \
# 79     SCEL  SAEZ   ACA    1    1  2017    Domingo         I    Air Canada
# 80     SCEL  SAEZ   ACA    2    1  2017      Lunes         I    Air Canada
# 81     SCEL  SAEZ   ACA    3    1  2017     Martes         I    Air Canada
# 82     SCEL  SAEZ   ACA    4    1  2017  Miercoles         I    Air Canada
# 83     SCEL  SAEZ   ACA    5    1  2017     Jueves         I    Air Canada
# ...     ...   ...   ...  ...  ...   ...        ...       ...           ...
# 68201  SCEL  SPJC   JAT   22   12  2017    Viernes         I  JetSmart SPA
# 68202  SCEL  SPJC   JAT   25   12  2017      Lunes         I  JetSmart SPA
# 68203  SCEL  SPJC   JAT   27   12  2017  Miercoles         I  JetSmart SPA
# 68204  SCEL  SPJC   JAT   29   12  2017    Viernes         I  JetSmart SPA
# 68205  SCEL  SPJC   JAT   31   12  2017    Domingo         I  JetSmart SPA
#
#        SIGLAORI      SIGLADES
# 79     Santiago  Buenos Aires
# 80     Santiago  Buenos Aires
# 81     Santiago  Buenos Aires
# 82     Santiago  Buenos Aires
# 83     Santiago  Buenos Aires
# ...         ...           ...
# 68201  Santiago          Lima
# 68202  Santiago          Lima
# 68203  Santiago          Lima
# 68204  Santiago          Lima
# 68205  Santiago          Lima
#
# [25506 rows x 18 columns]

# %%
df[(df['Fecha-I'].dt.hour>=19)|(df['Fecha-I'].dt.hour<5)]
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O  Vlo-O  \
# 0     2017-01-01 23:30:00   226  SCEL  KMIA   AAL 2017-01-01 23:33:00    226
# 1     2017-01-02 23:30:00   226  SCEL  KMIA   AAL 2017-01-02 23:39:00    226
# 2     2017-01-03 23:30:00   226  SCEL  KMIA   AAL 2017-01-03 23:39:00    226
# 3     2017-01-04 23:30:00   226  SCEL  KMIA   AAL 2017-01-04 23:33:00    226
# 4     2017-01-05 23:30:00   226  SCEL  KMIA   AAL 2017-01-05 23:28:00    226
# ...                   ...   ...   ...   ...   ...                 ...    ...
# 68192 2017-12-29 04:05:00   301  SCEL  SCCI   JAT 2017-12-29 04:00:00  301.0
# 68194 2017-12-18 20:11:00   305  SCEL  SCCI   JAT 2017-12-18 20:21:00  305.0
# 68195 2017-12-23 04:05:00   305  SCEL  SCCI   JAT 2017-12-23 04:01:00  305.0
# 68196 2017-12-25 20:11:00   305  SCEL  SCCI   JAT 2017-12-25 20:13:00  305.0
# 68197 2017-12-30 04:05:00   305  SCEL  SCCI   JAT 2017-12-30 04:00:00  305.0
#
#       Ori-O Des-O Emp-O  DIA  MES   AÑO     DIANOM TIPOVUELO  \
# 0      SCEL  KMIA   AAL    1    1  2017    Domingo         I
# 1      SCEL  KMIA   AAL    2    1  2017      Lunes         I
# 2      SCEL  KMIA   AAL    3    1  2017     Martes         I
# 3      SCEL  KMIA   AAL    4    1  2017  Miercoles         I
# 4      SCEL  KMIA   AAL    5    1  2017     Jueves         I
# ...     ...   ...   ...  ...  ...   ...        ...       ...
# 68192  SCEL  SCCI   JAT   29   12  2017    Viernes         N
# 68194  SCEL  SCCI   JAT   18   12  2017      Lunes         N
# 68195  SCEL  SCCI   JAT   23   12  2017     Sabado         N
# 68196  SCEL  SCCI   JAT   25   12  2017      Lunes         N
# 68197  SCEL  SCCI   JAT   30   12  2017     Sabado         N
#
#                    OPERA  SIGLAORI      SIGLADES
# 0      American Airlines  Santiago         Miami
# 1      American Airlines  Santiago         Miami
# 2      American Airlines  Santiago         Miami
# 3      American Airlines  Santiago         Miami
# 4      American Airlines  Santiago         Miami
# ...                  ...       ...           ...
# 68192       JetSmart SPA  Santiago  Punta Arenas
# 68194       JetSmart SPA  Santiago  Punta Arenas
# 68195       JetSmart SPA  Santiago  Punta Arenas
# 68196       JetSmart SPA  Santiago  Punta Arenas
# 68197       JetSmart SPA  Santiago  Punta Arenas
#
# [17348 rows x 18 columns]

# %%
condicionfecha=(df['Fecha-I']>='2017-12-15') | (df['Fecha-I']<='2017-03-03') | ((df['Fecha-I']>='2017-07-15') & (df['Fecha-I']<='2017-07-31')) | ((df['Fecha-I']>='2017-09-11') & (df['Fecha-I']<='2017-09-30'))
df['temporada_alta']=np.where(condicionfecha,1,0)
df['dif_min']=np.where(df['Fecha-O']>df['Fecha-I'],pd.to_timedelta(df['Fecha-O']-df['Fecha-I']).dt.seconds/60,0)
df['atraso_15']=np.where(df['dif_min']>15,1,0)
condicionmañana=(df['Fecha-I'].dt.hour>=5)&(df['Fecha-I'].dt.hour<12)
condiciontarde=(df['Fecha-I'].dt.hour>=12)&(df['Fecha-I'].dt.hour<19)
condicionnoche=(df['Fecha-I'].dt.hour>=19)|(df['Fecha-I'].dt.hour<5)
df['periodo_dia']=np.where(condicionmañana,'mañana',np.where(condiciontarde,'tarde','noche'))
df
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O  Vlo-O  \
# 0     2017-01-01 23:30:00   226  SCEL  KMIA   AAL 2017-01-01 23:33:00    226
# 1     2017-01-02 23:30:00   226  SCEL  KMIA   AAL 2017-01-02 23:39:00    226
# 2     2017-01-03 23:30:00   226  SCEL  KMIA   AAL 2017-01-03 23:39:00    226
# 3     2017-01-04 23:30:00   226  SCEL  KMIA   AAL 2017-01-04 23:33:00    226
# 4     2017-01-05 23:30:00   226  SCEL  KMIA   AAL 2017-01-05 23:28:00    226
# ...                   ...   ...   ...   ...   ...                 ...    ...
# 68201 2017-12-22 14:55:00   400  SCEL  SPJC   JAT 2017-12-22 15:41:00  400.0
# 68202 2017-12-25 14:55:00   400  SCEL  SPJC   JAT 2017-12-25 15:11:00  400.0
# 68203 2017-12-27 14:55:00   400  SCEL  SPJC   JAT 2017-12-27 15:35:00  400.0
# 68204 2017-12-29 14:55:00   400  SCEL  SPJC   JAT 2017-12-29 15:08:00  400.0
# 68205 2017-12-31 14:55:00   400  SCEL  SPJC   JAT 2017-12-31 15:04:00  400.0
#
#       Ori-O Des-O Emp-O  ...   AÑO     DIANOM  TIPOVUELO              OPERA  \
# 0      SCEL  KMIA   AAL  ...  2017    Domingo          I  American Airlines
# 1      SCEL  KMIA   AAL  ...  2017      Lunes          I  American Airlines
# 2      SCEL  KMIA   AAL  ...  2017     Martes          I  American Airlines
# 3      SCEL  KMIA   AAL  ...  2017  Miercoles          I  American Airlines
# 4      SCEL  KMIA   AAL  ...  2017     Jueves          I  American Airlines
# ...     ...   ...   ...  ...   ...        ...        ...                ...
# 68201  SCEL  SPJC   JAT  ...  2017    Viernes          I       JetSmart SPA
# 68202  SCEL  SPJC   JAT  ...  2017      Lunes          I       JetSmart SPA
# 68203  SCEL  SPJC   JAT  ...  2017  Miercoles          I       JetSmart SPA
# 68204  SCEL  SPJC   JAT  ...  2017    Viernes          I       JetSmart SPA
# 68205  SCEL  SPJC   JAT  ...  2017    Domingo          I       JetSmart SPA
#
#        SIGLAORI SIGLADES temporada_alta dif_min  atraso_15  periodo_dia
# 0      Santiago    Miami              1     3.0          0        noche
# 1      Santiago    Miami              1     9.0          0        noche
# 2      Santiago    Miami              1     9.0          0        noche
# 3      Santiago    Miami              1     3.0          0        noche
# 4      Santiago    Miami              1     0.0          0        noche
# ...         ...      ...            ...     ...        ...          ...
# 68201  Santiago     Lima              1    46.0          1        tarde
# 68202  Santiago     Lima              1    16.0          1        tarde
# 68203  Santiago     Lima              1    40.0          1        tarde
# 68204  Santiago     Lima              1    13.0          0        tarde
# 68205  Santiago     Lima              1     9.0          0        tarde
#
# [68206 rows x 22 columns]

# %%
df['Fecha-I'][df['periodo_dia']=='mañana']
# Out:
# 201     2017-01-01 10:35:00
# 202     2017-01-02 10:35:00
# 203     2017-01-03 10:35:00
# 204     2017-01-04 10:35:00
# 205     2017-01-05 10:35:00
#                 ...
# 68168   2017-12-15 08:55:00
# 68171   2017-12-20 11:57:00
# 68173   2017-12-22 08:55:00
# 68177   2017-12-27 11:57:00
# 68179   2017-12-29 08:55:00
# Name: Fecha-I, Length: 25352, dtype: datetime64[ns]

# %% [markdown]
# ### Exportacion columnas a archivo synthetic_features.csv

# %%
df_exp=pd.DataFrame(df.loc[:,['temporada_alta','dif_min','atraso_15','periodo_dia']])
df_exp
# Out:
#        temporada_alta  dif_min  atraso_15 periodo_dia
# 0                   1      3.0          0       noche
# 1                   1      9.0          0       noche
# 2                   1      9.0          0       noche
# 3                   1      3.0          0       noche
# 4                   1      0.0          0       noche
# ...               ...      ...        ...         ...
# 68201               1     46.0          1       tarde
# 68202               1     16.0          1       tarde
# 68203               1     40.0          1       tarde
# 68204               1     13.0          0       tarde
# 68205               1      9.0          0       tarde
#
# [68206 rows x 4 columns]

# %% [markdown]
# ### Se asume que el archivo csv se creara en la misma carpeta (repositorio) en el que se encuentra este jupyternotebook. Por lo mismo el path no lleva toda la ruta expecifica del archivo.

# %%
df_exp.to_csv('synthetic_features.csv',index=False)

# %% [markdown]
# # 3.
# # ¿Cómo se compone la tasa de atraso por destino, aerolínea, mes del año, día de la semana, temporada, tipo de vuelo?
# # ¿Qué variables esperarías que más influyeran en predecir atrasos?

# %% [markdown]
# ### Distribucion tasa atraso

# %%
plt.figure(figsize=(20,10))
sns.histplot(df['dif_min'],bins=int(1+3.322*m.log10(len(df['dif_min']))))
# Out:
# <AxesSubplot:xlabel='dif_min', ylabel='Count'>

# %%
print('Tasa atraso general:')
df['dif_min'].mean()
# Out:
# Tasa atraso general:
# 10.11576694132481

# %% [markdown]
# Es posible apreciar que la tasa de atraso se distribuye poisson con media 10.11

# %% [markdown]
# ### Analisis tasa atraso por  variable

# %%
df.corr()
# Out:
#                      DIA       MES       AÑO  temporada_alta   dif_min  \
# DIA             1.000000  0.014318 -0.009073        0.183613 -0.005400
# MES             0.014318  1.000000 -0.008642       -0.293902  0.075682
# AÑO            -0.009073 -0.008642  1.000000        0.007793  0.002726
# temporada_alta  0.183613 -0.293902  0.007793        1.000000  0.019182
# dif_min        -0.005400  0.075682  0.002726        0.019182  1.000000
# atraso_15      -0.002517  0.083416  0.004394        0.020332  0.724576
#
#                 atraso_15
# DIA             -0.002517
# MES              0.083416
# AÑO              0.004394
# temporada_alta   0.020332
# dif_min          0.724576
# atraso_15        1.000000

# %%
bydestino=df.groupby('Des-O').mean()
bydestino['dif_min'].describe()
# Out:
# count     63.000000
# mean      13.587346
# std       15.483313
# min        0.000000
# 25%        7.939158
# 50%       10.576063
# 75%       14.168634
# max      113.000000
# Name: dif_min, dtype: float64

# %%
plt.figure(figsize=(17,10))
bydestino['dif_min'].plot(kind='bar')
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(20,10))
sns.histplot(bydestino['dif_min'],bins=round(1+3.322*m.log10(len(bydestino['dif_min']))))
# Out:
# <AxesSubplot:xlabel='dif_min', ylabel='Count'>

# %%
pd.crosstab(index=df['Des-O'],columns=df['atraso_15'], margins=True)
# Out:
# atraso_15      0      1    All
# Des-O
# CYYZ         194     89    283
# EGLL         176     29    205
# EGYP           0      1      1
# KATL         337     21    358
# KDFW         332     25    357
# ...          ...    ...    ...
# SULS           5      1      6
# SUMU         846    220   1066
# YMML          18     21     39
# YSSY          81    113    194
# All        55592  12614  68206
#
# [64 rows x 3 columns]

# %%
plot = pd.crosstab(index=df['Des-O'],columns=df['atraso_15']).apply(lambda r: r/r.sum(),axis=1).plot(kind='bar',figsize=(15,7))
#.apply(lambda r: r/r.sum() *100,axis=1)

# %%
byaerolinea=df.groupby('OPERA').mean()
byaerolinea['dif_min'].describe()
# Out:
# count    23.000000
# mean     10.924337
# std       8.399142
# min       2.079772
# 25%       4.842669
# 50%       8.800000
# 75%      12.680598
# max      32.306122
# Name: dif_min, dtype: float64

# %%
plt.figure(figsize=(20,10))
byaerolinea['dif_min'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='OPERA'>

# %%
plt.figure(figsize=(20,10))
sns.histplot(byaerolinea['dif_min'],bins=round(1+3.322*m.log10(len(byaerolinea['dif_min']))))
# Out:
# <AxesSubplot:xlabel='dif_min', ylabel='Count'>

# %%
pd.crosstab(index=df['OPERA'],columns=df['atraso_15'], margins=True)
# Out:
# atraso_15                     0      1    All
# OPERA
# Aerolineas Argentinas      1481    468   1949
# Aeromexico                  341     10    351
# Air Canada                  307    258    565
# Air France                  328     30    358
# Alitalia                    230     29    259
# American Airlines           706     51    757
# Austral                      59     15     74
# Avianca                     846    306   1152
# British Airways             176     29    205
# Copa Air                   1734    116   1850
# Delta Air                   337     21    358
# Gol Trans                   519    287    806
# Grupo LATAM               33586   7306  40892
# Iberia                      326     36    362
# JetSmart SPA                899    196   1095
# K.L.M.                      230     21    251
# Lacsa                        81     11     92
# Latin American Wings        993    681   1674
# Oceanair Linhas Aereas      236     43    279
# Plus Ultra Lineas Aereas     19     30     49
# Qantas Airways               82    113    195
# Sky Airline               11758   2540  14298
# United Airlines             318     17    335
# All                       55592  12614  68206

# %%
plot = pd.crosstab(index=df['OPERA'],columns=df['atraso_15']).apply(lambda r: r/r.sum(),axis=1).plot(kind='bar',figsize=(15,7))

# %%
bymes=df.groupby('MES').mean()
bymes['dif_min'].describe()
# Out:
# count    12.000000
# mean     10.002990
# std       2.567078
# min       6.919920
# 25%       8.610508
# 50%       9.614579
# 75%      10.773483
# max      16.045895
# Name: dif_min, dtype: float64

# %%
plt.figure(figsize=(20,10))
bymes['dif_min'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='MES'>

# %%
plt.figure(figsize=(20,10))
sns.histplot(bymes['dif_min'],bins=round(1+3.322*m.log10(len(bymes['dif_min']))))
# Out:
# <AxesSubplot:xlabel='dif_min', ylabel='Count'>

# %%
pd.crosstab(index=df['MES'],columns=df['atraso_15'], margins=True)
# Out:
# atraso_15      0      1    All
# MES
# 1           5130    978   6108
# 2           4718    843   5561
# 3           4851    631   5482
# 4           4435    585   5020
# 5           4413    827   5240
# 6           4129    852   4981
# 7           4234   1758   5992
# 8           4748    996   5744
# 9           4643    967   5610
# 10          4669   1363   6032
# 11          4881   1199   6080
# 12          4741   1615   6356
# All        55592  12614  68206

# %%
plot = pd.crosstab(index=df['MES'],columns=df['atraso_15']).apply(lambda r: r/r.sum(),axis=1).plot(kind='bar',figsize=(15,7))

# %%
bydia=df.groupby('DIANOM').mean()
bydia['dif_min'].describe()
# Out:
# count     7.000000
# mean     10.082629
# std       0.980736
# min       9.017762
# 25%       9.441898
# 50%       9.553281
# 75%      10.716269
# max      11.691022
# Name: dif_min, dtype: float64

# %%
plt.figure(figsize=(20,10))
bydia['dif_min'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='DIANOM'>

# %%
plt.figure(figsize=(20,10))
sns.histplot(bydia['dif_min'],bins=round(1+3.322*m.log10(len(bydia['dif_min']))))
# Out:
# <AxesSubplot:xlabel='dif_min', ylabel='Count'>

# %%
pd.crosstab(index=df['DIANOM'],columns=df['atraso_15'], margins=True)
# Out:
# atraso_15      0      1    All
# DIANOM
# Domingo     8218   1578   9796
# Jueves      8206   2045  10251
# Lunes       8083   2048  10131
# Martes      8028   1634   9662
# Miercoles   8061   1661   9722
# Sabado      6989   1363   8352
# Viernes     8007   2285  10292
# All        55592  12614  68206

# %%
plot = pd.crosstab(index=df['DIANOM'],columns=df['atraso_15']).apply(lambda r: r/r.sum(),axis=1).plot(kind='bar',figsize=(15,7))

# %%
bytemporada=df.groupby('temporada_alta').mean()
bytemporada['dif_min'].describe()
# Out:
# count     2.000000
# mean     10.248827
# std       0.539637
# min       9.867246
# 25%      10.058037
# 50%      10.248827
# 75%      10.439618
# max      10.630408
# Name: dif_min, dtype: float64

# %%
plt.figure(figsize=(20,10))
bytemporada['dif_min'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='temporada_alta'>

# %%
plt.figure(figsize=(20,10))
sns.histplot(bytemporada['dif_min'],bins=round(1+3.322*m.log10(len(bytemporada['dif_min']))))
# Out:
# <AxesSubplot:xlabel='dif_min', ylabel='Count'>

# %%
pd.crosstab(index=df['temporada_alta'],columns=df['atraso_15'], margins=True)
# Out:
# atraso_15           0      1    All
# temporada_alta
# 0               37741   8254  45995
# 1               17851   4360  22211
# All             55592  12614  68206

# %%
plot = pd.crosstab(index=df['temporada_alta'],columns=df['atraso_15']).apply(lambda r: r/r.sum(),axis=1).plot(kind='bar',figsize=(15,7))

# %%
bytipovuelo=df.groupby('TIPOVUELO').mean()
bytipovuelo['dif_min'].describe()
# Out:
# count     2.000000
# mean     10.257267
# std       2.383655
# min       8.571769
# 25%       9.414518
# 50%      10.257267
# 75%      11.100016
# max      11.942766
# Name: dif_min, dtype: float64

# %%
plt.figure(figsize=(20,10))
bytipovuelo['dif_min'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='TIPOVUELO'>

# %%
plt.figure(figsize=(20,10))
sns.histplot(bytipovuelo['dif_min'],bins=round(1+3.322*m.log10(len(bytipovuelo['dif_min']))))
# Out:
# <AxesSubplot:xlabel='dif_min', ylabel='Count'>

# %%
pd.crosstab(index=df['TIPOVUELO'],columns=df['atraso_15'], margins=True)
# Out:
# atraso_15      0      1    All
# TIPOVUELO
# I          24192   7048  31240
# N          31400   5566  36966
# All        55592  12614  68206

# %%
plot = pd.crosstab(index=df['TIPOVUELO'],columns=df['atraso_15']).apply(lambda r: r/r.sum(),axis=1).plot(kind='bar',figsize=(15,7))

# %% [markdown]
# ### Analisis de Experimentos (ANOVA)

# %%
import copy
df_e=copy.copy(df)

# %%
df_e.rename(columns={'Des-O':'DesO'},inplace=True)
df_e.rename(columns={'Emp-O':'EmpO'},inplace=True)

# %%
df_e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68206 entries, 0 to 68205
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Fecha-I         68206 non-null  datetime64[ns]
#  1   Vlo-I           68206 non-null  object
#  2   Ori-I           68206 non-null  object
#  3   Des-I           68206 non-null  object
#  4   Emp-I           68206 non-null  object
#  5   Fecha-O         68206 non-null  datetime64[ns]
#  6   Vlo-O           68205 non-null  object
#  7   Ori-O           68206 non-null  object
#  8   DesO            68206 non-null  object
#  9   EmpO            68206 non-null  object
#  10  DIA             68206 non-null  int64
#  11  MES             68206 non-null  int64
#  12  AÑO             68206 non-null  int64
#  13  DIANOM          68206 non-null  object
#  14  TIPOVUELO       68206 non-null  object
#  15  OPERA           68206 non-null  object
#  16  SIGLAORI        68206 non-null  object
#  17  SIGLADES        68206 non-null  object
#  18  temporada_alta  68206 non-null  int32
#  19  dif_min         68206 non-null  float64
#  20  atraso_15       68206 non-null  int32
#  21  periodo_dia     68206 non-null  object
# dtypes: datetime64[ns](2), float64(1), int32(2), int64(3), object(14)
# memory usage: 10.9+ MB

# %%
formula='dif_min ~ C(DesO) + C(OPERA) + C(MES) + C(DIANOM) + C(temporada_alta) + C(TIPOVUELO)'
modelo = ols(formula = formula, data=df_e).fit()
modelo.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                dif_min   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     52.80
# Date:                Mon, 14 Mar 2022   Prob (F-statistic):               0.00
# Time:                        04:21:17   Log-Likelihood:            -2.9385e+05
# No. Observations:               68206   AIC:                         5.879e+05
# Df Residuals:                   68108   BIC:                         5.888e+05
# Df Model:                          97
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                               -6.1849      1.669     -3.705      0.000      -9.457      -2.913
# C(DesO)[T.EGLL]                      -2.707e+09   5.82e+10     -0.047      0.963   -1.17e+11    1.11e+11
# C(DesO)[T.EGYP]                         52.0319     18.063      2.881      0.004      16.628      87.436
# C(DesO)[T.KATL]                       5.267e+09    2.2e+10      0.240      0.810   -3.78e+10    4.83e+10
# C(DesO)[T.KDFW]                         15.1276      2.159      7.008      0.000      10.897      19.359
# C(DesO)[T.KIAD]                       1.858e+09    7.3e+09      0.255      0.799   -1.24e+10    1.62e+10
# C(DesO)[T.KIAH]                       1.858e+09    7.3e+09      0.255      0.799   -1.24e+10    1.62e+10
# C(DesO)[T.KJFK]                         14.4652      1.808      8.001      0.000      10.922      18.009
# C(DesO)[T.KLAX]                         15.4941      2.124      7.294      0.000      11.331      19.658
# C(DesO)[T.KMCO]                         14.5838      3.458      4.217      0.000       7.805      21.362
# C(DesO)[T.KMIA]                         16.4984      1.716      9.613      0.000      13.135      19.862
# C(DesO)[T.LEMD]                         14.0375      1.756      7.994      0.000      10.596      17.479
# C(DesO)[T.LFPG]                         80.0680     18.264      4.384      0.000      44.270     115.866
# C(DesO)[T.LIRF]                      -4.514e+10   4.52e+11     -0.100      0.921   -9.32e+11    8.42e+11
# C(DesO)[T.MDPC]                         16.9790      2.906      5.843      0.000      11.284      22.674
# C(DesO)[T.MMMX]                         11.5070      1.830      6.288      0.000       7.920      15.094
# C(DesO)[T.MMUN]                         10.1039      2.753      3.670      0.000       4.707      15.500
# C(DesO)[T.MPTO]                       2.895e+12   1.16e+13      0.249      0.804   -1.99e+13    2.57e+13
# C(DesO)[T.NZAA]                         20.5353      1.822     11.274      0.000      16.965      24.105
# C(DesO)[T.SAAR]                         19.7903      2.193      9.025      0.000      15.492      24.088
# C(DesO)[T.SABE]                         15.5537      1.602      9.710      0.000      12.414      18.693
# C(DesO)[T.SACO]                         16.0769      1.656      9.711      0.000      12.832      19.322
# C(DesO)[T.SAEZ]                         13.4141      1.514      8.860      0.000      10.447      16.382
# C(DesO)[T.SAME]                         15.5015      1.619      9.575      0.000      12.328      18.675
# C(DesO)[T.SANT]                         14.8722      3.311      4.492      0.000       8.383      21.362
# C(DesO)[T.SANU]                         13.9693      3.420      4.085      0.000       7.266      20.672
# C(DesO)[T.SAWH]                         23.8452      7.519      3.171      0.002       9.108      38.582
# C(DesO)[T.SAZN]                         10.5280      3.346      3.147      0.002       3.970      17.086
# C(DesO)[T.SAZS]                         21.2510     12.823      1.657      0.097      -3.881      46.383
# C(DesO)[T.SBCT]                          7.1048     10.514      0.676      0.499     -13.503      27.712
# C(DesO)[T.SBFI]                          4.0975     12.828      0.319      0.749     -21.046      29.241
# C(DesO)[T.SBFL]                         10.4769      2.105      4.976      0.000       6.350      14.604
# C(DesO)[T.SBGL]                         16.2325      1.628      9.968      0.000      13.041      19.424
# C(DesO)[T.SBGR]                         14.4757      1.593      9.086      0.000      11.353      17.598
# C(DesO)[T.SCAR]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SCAT]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SCBA]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SCCF]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SCCI]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SCDA]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SCFA]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SCIE]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SCIP]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SCJO]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SCNT]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SCPQ]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SCQP]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SCSE]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SCTE]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SCVD]                      -8.703e+11   8.77e+12     -0.099      0.921   -1.81e+13    1.63e+13
# C(DesO)[T.SEGU]                         13.0695      1.787      7.312      0.000       9.566      16.573
# C(DesO)[T.SEQM]                         53.1379     12.822      4.144      0.000      28.007      78.268
# C(DesO)[T.SGAS]                         14.8759      1.954      7.613      0.000      11.046      18.706
# C(DesO)[T.SKBO]                         15.0605      1.666      9.042      0.000      11.796      18.325
# C(DesO)[T.SLCB]                        113.9818     18.064      6.310      0.000      78.577     149.387
# C(DesO)[T.SLLP]                         10.9914      1.993      5.515      0.000       7.085      14.897
# C(DesO)[T.SLVR]                         15.2047      2.263      6.718      0.000      10.769      19.641
# C(DesO)[T.SPJC]                         12.0767      1.577      7.657      0.000       8.985      15.168
# C(DesO)[T.SPSO]                          1.0334     18.064      0.057      0.954     -34.373      36.440
# C(DesO)[T.SULS]                          9.1286      7.529      1.213      0.225      -5.628      23.885
# C(DesO)[T.SUMU]                         12.7613      1.649      7.737      0.000       9.528      15.994
# C(DesO)[T.YMML]                         19.7258      3.311      5.958      0.000      13.237      26.215
# C(DesO)[T.YSSY]                         42.9749     18.343      2.343      0.019       7.023      78.927
# C(OPERA)[T.Aeromexico]                  -6.2573      1.468     -4.263      0.000      -9.134      -3.381
# C(OPERA)[T.Air Canada]                  20.2538      1.224     16.543      0.000      17.854      22.653
# C(OPERA)[T.Air France]                 -72.7303     18.231     -3.989      0.000    -108.463     -36.998
# C(OPERA)[T.Alitalia]                  4.514e+10   4.52e+11      0.100      0.921   -8.42e+11    9.32e+11
# C(OPERA)[T.American Airlines]           -8.5010      1.279     -6.647      0.000     -11.008      -5.994
# C(OPERA)[T.Austral]                     -4.1979      2.168     -1.936      0.053      -8.448       0.052
# C(OPERA)[T.Avianca]                      2.1247      0.896      2.373      0.018       0.370       3.880
# C(OPERA)[T.British Airways]           2.707e+09   5.82e+10      0.047      0.963   -1.11e+11    1.17e+11
# C(OPERA)[T.Copa Air]                 -2.895e+12   1.16e+13     -0.249      0.804   -2.57e+13    1.99e+13
# C(OPERA)[T.Delta Air]                -5.267e+09    2.2e+10     -0.240      0.810   -4.83e+10    3.78e+10
# C(OPERA)[T.Gol Trans]                    2.8012      0.889      3.150      0.002       1.058       4.544
# C(OPERA)[T.Grupo LATAM]                  1.2121      0.550      2.205      0.027       0.135       2.290
# C(OPERA)[T.Iberia]                      -4.9668      1.364     -3.642      0.000      -7.640      -2.294
# C(OPERA)[T.JetSmart SPA]                 0.9057      0.788      1.150      0.250      -0.638       2.450
# C(OPERA)[T.K.L.M.]                      -4.7717      1.281     -3.724      0.000      -7.283      -2.260
# C(OPERA)[T.Lacsa]                       -2.8937      1.977     -1.464      0.143      -6.769       0.982
# C(OPERA)[T.Latin American Wings]        16.5561      0.724     22.860      0.000      15.137      17.976
# C(OPERA)[T.Oceanair Linhas Aereas]      -2.9689      1.259     -2.357      0.018      -5.437      -0.501
# C(OPERA)[T.Plus Ultra Lineas Aereas]    17.7480      2.766      6.417      0.000      12.327      23.169
# C(OPERA)[T.Qantas Airways]             -12.5732     18.240     -0.689      0.491     -48.323      23.177
# C(OPERA)[T.Sky Airline]                  1.4875      0.573      2.594      0.009       0.364       2.611
# C(OPERA)[T.United Airlines]          -1.858e+09    7.3e+09     -0.255      0.799   -1.62e+10    1.24e+10
# C(MES)[T.2]                             -0.1580      0.334     -0.473      0.636      -0.812       0.496
# C(MES)[T.3]                             -0.9993      0.415     -2.409      0.016      -1.812      -0.186
# C(MES)[T.4]                             -1.1223      0.432     -2.597      0.009      -1.969      -0.275
# C(MES)[T.5]                              0.4979      0.429      1.161      0.246      -0.343       1.339
# C(MES)[T.6]                              1.2096      0.433      2.792      0.005       0.361       2.059
# C(MES)[T.7]                              7.1903      0.352     20.440      0.000       6.501       7.880
# C(MES)[T.8]                              1.3313      0.423      3.144      0.002       0.501       2.161
# C(MES)[T.9]                              0.7368      0.348      2.119      0.034       0.055       1.418
# C(MES)[T.10]                             4.1981      0.421      9.975      0.000       3.373       5.023
# C(MES)[T.11]                             2.1851      0.421      5.195      0.000       1.361       3.010
# C(MES)[T.12]                             4.0249      0.347     11.611      0.000       3.345       4.704
# C(DIANOM)[T.Jueves]                      1.7718      0.256      6.925      0.000       1.270       2.273
# C(DIANOM)[T.Lunes]                       2.0581      0.256      8.032      0.000       1.556       2.560
# C(DIANOM)[T.Martes]                      0.6467      0.259      2.496      0.013       0.139       1.155
# C(DIANOM)[T.Miercoles]                   0.7529      0.259      2.908      0.004       0.245       1.260
# C(DIANOM)[T.Sabado]                      0.4342      0.270      1.611      0.107      -0.094       0.963
# C(DIANOM)[T.Viernes]                     2.7835      0.255     10.908      0.000       2.283       3.284
# C(temporada_alta)[T.1]                   0.8990      0.262      3.429      0.001       0.385       1.413
# C(TIPOVUELO)[T.N]                     8.703e+11   8.77e+12      0.099      0.921   -1.63e+13    1.81e+13
# ==============================================================================
# Omnibus:                    54070.066   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1200842.576
# Skew:                           3.766   Prob(JB):                         0.00
# Kurtosis:                      22.127   Cond. No.                     4.04e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.98e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
anova = anova_lm(modelo)
anova
# Out:
#                         df        sum_sq       mean_sq           F  \
# C(DesO)               62.0  6.501287e+05  10485.946244   32.387502
# C(OPERA)              22.0  5.577168e+05  25350.764055   78.299840
# C(MES)                11.0  3.871517e+05  35195.612716  108.707210
# C(DIANOM)              6.0  5.973602e+04   9956.002574   30.750687
# C(temporada_alta)      1.0  3.807332e+03   3807.331643   11.759545
# C(TIPOVUELO)           1.0  3.548354e+00      3.548354    0.010960
# Residual           68108.0  2.205100e+07    323.765209         NaN
#
#                           PR(>F)
# C(DesO)             0.000000e+00
# C(OPERA)            0.000000e+00
# C(MES)             2.179137e-247
# C(DIANOM)           4.223122e-37
# C(temporada_alta)   6.056784e-04
# C(TIPOVUELO)        9.166234e-01
# Residual                     NaN

# %%
formula='dif_min ~ C(DesO)'
modelo = ols(formula = formula, data=df_e).fit()
modelo.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                dif_min   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     30.99
# Date:                Mon, 14 Mar 2022   Prob (F-statistic):               0.00
# Time:                        04:21:19   Log-Likelihood:            -2.9537e+05
# No. Observations:               68206   AIC:                         5.909e+05
# Df Residuals:                   68143   BIC:                         5.914e+05
# Df Model:                          62
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          17.1307      1.093     15.666      0.000      14.987      19.274
# C(DesO)[T.EGLL]    -8.3161      1.687     -4.929      0.000     -11.623      -5.009
# C(DesO)[T.EGYP]    32.8693     18.428      1.784      0.074      -3.249      68.988
# C(DesO)[T.KATL]   -13.7872      1.463     -9.423      0.000     -16.655     -10.919
# C(DesO)[T.KDFW]   -13.6041      1.464     -9.292      0.000     -16.474     -10.734
# C(DesO)[T.KIAD]   -17.1307     18.428     -0.930      0.353     -53.249      18.988
# C(DesO)[T.KIAH]   -13.4062      1.486     -9.020      0.000     -16.319     -10.493
# C(DesO)[T.KJFK]    -4.5129      1.443     -3.128      0.002      -7.341      -1.685
# C(DesO)[T.KLAX]    -3.4791      1.838     -1.893      0.058      -7.082       0.124
# C(DesO)[T.KMCO]    -3.4837      3.339     -1.043      0.297     -10.028       3.061
# C(DesO)[T.KMIA]    -6.3492      1.236     -5.135      0.000      -8.773      -3.926
# C(DesO)[T.LEMD]    -6.5547      1.255     -5.224      0.000      -9.014      -4.095
# C(DesO)[T.LFPG]   -12.6656      1.462     -8.661      0.000     -15.532      -9.799
# C(DesO)[T.LIRF]    -9.9493      1.582     -6.290      0.000     -13.050      -6.849
# C(DesO)[T.MDPC]    -2.8715      2.732     -1.051      0.293      -8.226       2.483
# C(DesO)[T.MMMX]   -11.2707      1.296     -8.698      0.000     -13.811      -8.731
# C(DesO)[T.MMUN]    -9.0831      2.563     -3.544      0.000     -14.106      -4.060
# C(DesO)[T.MPTO]   -13.5340      1.174    -11.527      0.000     -15.835     -11.233
# C(DesO)[T.NZAA]     1.5313      1.461      1.048      0.294      -1.331       4.394
# C(DesO)[T.SAAR]     2.0384      1.919      1.062      0.288      -1.724       5.800
# C(DesO)[T.SABE]    -4.0312      1.142     -3.529      0.000      -6.270      -1.792
# C(DesO)[T.SACO]    -2.9685      1.236     -2.403      0.016      -5.390      -0.547
# C(DesO)[T.SAEZ]    -4.5007      1.140     -3.947      0.000      -6.736      -2.266
# C(DesO)[T.SAME]    -1.1104      1.185     -0.937      0.349      -3.433       1.212
# C(DesO)[T.SANT]    -1.8150      3.178     -0.571      0.568      -8.044       4.414
# C(DesO)[T.SANU]    -2.7022      3.296     -0.820      0.412      -9.162       3.758
# C(DesO)[T.SAWH]     7.3693      7.589      0.971      0.332      -7.505      22.244
# C(DesO)[T.SAZN]    -7.5632      3.216     -2.352      0.019     -13.866      -1.260
# C(DesO)[T.SAZS]     1.3693     13.053      0.105      0.916     -24.215      26.954
# C(DesO)[T.SBCT]   -15.1307     10.677     -1.417      0.156     -36.057       5.796
# C(DesO)[T.SBFI]   -14.6307     13.053     -1.121      0.262     -40.215      10.954
# C(DesO)[T.SBFL]    -8.1246      1.812     -4.483      0.000     -11.677      -4.572
# C(DesO)[T.SBGL]    -2.3851      1.196     -1.993      0.046      -4.730      -0.040
# C(DesO)[T.SBGR]    -4.2579      1.136     -3.748      0.000      -6.485      -2.031
# C(DesO)[T.SCAR]    -9.2112      1.155     -7.973      0.000     -11.476      -6.947
# C(DesO)[T.SCAT]    -9.1959      1.177     -7.812      0.000     -11.503      -6.889
# C(DesO)[T.SCBA]    -7.7338      1.265     -6.116      0.000     -10.212      -5.255
# C(DesO)[T.SCCF]   -10.1873      1.123     -9.070      0.000     -12.389      -7.986
# C(DesO)[T.SCCI]    -7.6766      1.165     -6.591      0.000      -9.959      -5.394
# C(DesO)[T.SCDA]    -7.8825      1.134     -6.951      0.000     -10.105      -5.660
# C(DesO)[T.SCFA]    -9.1873      1.120     -8.204      0.000     -11.382      -6.992
# C(DesO)[T.SCIE]    -7.9399      1.132     -7.017      0.000     -10.158      -5.722
# C(DesO)[T.SCIP]    -5.1728      1.394     -3.710      0.000      -7.906      -2.440
# C(DesO)[T.SCJO]    -6.0844      1.582     -3.846      0.000      -9.185      -2.984
# C(DesO)[T.SCNT]   -11.4725      2.341     -4.901      0.000     -16.060      -6.885
# C(DesO)[T.SCPQ]   -10.2371      1.623     -6.306      0.000     -13.419      -7.055
# C(DesO)[T.SCQP]    -8.3316      1.152     -7.234      0.000     -10.589      -6.074
# C(DesO)[T.SCSE]    -8.1187      1.156     -7.024      0.000     -10.384      -5.853
# C(DesO)[T.SCTE]    -7.7064      1.128     -6.829      0.000      -9.918      -5.495
# C(DesO)[T.SCVD]    -8.2011      1.283     -6.394      0.000     -10.715      -5.687
# C(DesO)[T.SEGU]    -6.2326      1.413     -4.410      0.000      -9.003      -3.462
# C(DesO)[T.SEQM]    34.8693     13.053      2.671      0.008       9.285      60.454
# C(DesO)[T.SGAS]    -3.6868      1.629     -2.263      0.024      -6.880      -0.494
# C(DesO)[T.SKBO]    -3.5279      1.186     -2.974      0.003      -5.853      -1.203
# C(DesO)[T.SLCB]    95.8693     18.428      5.202      0.000      59.751     131.988
# C(DesO)[T.SLLP]    -7.9537      1.678     -4.741      0.000     -11.242      -4.665
# C(DesO)[T.SLVR]    -2.9557      2.004     -1.475      0.140      -6.883       0.972
# C(DesO)[T.SPJC]    -4.4539      1.122     -3.968      0.000      -6.654      -2.254
# C(DesO)[T.SPSO]   -15.1307     18.428     -0.821      0.412     -51.249      20.988
# C(DesO)[T.SULS]    -7.6307      7.589     -1.005      0.315     -22.505       7.244
# C(DesO)[T.SUMU]    -6.2518      1.230     -5.082      0.000      -8.663      -3.841
# C(DesO)[T.YMML]     2.2282      3.142      0.709      0.478      -3.930       8.387
# C(DesO)[T.YSSY]    10.0033      1.715      5.834      0.000       6.643      13.364
# ==============================================================================
# Omnibus:                    54838.105   Durbin-Watson:                   1.714
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1209604.749
# Skew:                           3.853   Prob(JB):                         0.00
# Kurtosis:                      22.138   Cond. No.                         270.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
anova = anova_lm(modelo)
anova
# Out:
#                df        sum_sq       mean_sq          F  PR(>F)
# C(DesO)      62.0  6.501287e+05  10485.946244  30.987543     0.0
# Residual  68143.0  2.305907e+07    338.392311        NaN     NaN

# %%
formula='dif_min ~ C(OPERA)'
modelo = ols(formula = formula, data=df_e).fit()
modelo.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                dif_min   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     111.9
# Date:                Mon, 14 Mar 2022   Prob (F-statistic):               0.00
# Time:                        04:21:19   Log-Likelihood:            -2.9511e+05
# No. Observations:               68206   AIC:                         5.903e+05
# Df Residuals:                   68183   BIC:                         5.905e+05
# Df Model:                          22
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                               12.1668      0.415     29.320      0.000      11.353      12.980
# C(OPERA)[T.Aeromexico]                 -10.0870      1.062     -9.496      0.000     -12.169      -8.005
# C(OPERA)[T.Air Canada]                  11.6704      0.875     13.333      0.000       9.955      13.386
# C(OPERA)[T.Air France]                  -7.9545      1.053     -7.551      0.000     -10.019      -5.890
# C(OPERA)[T.Alitalia]                    -4.9853      1.212     -4.115      0.000      -7.360      -2.611
# C(OPERA)[T.American Airlines]           -7.9316      0.785    -10.110      0.000      -9.469      -6.394
# C(OPERA)[T.Austral]                     -3.3830      2.170     -1.559      0.119      -7.636       0.870
# C(OPERA)[T.Avianca]                      1.0277      0.681      1.509      0.131      -0.307       2.362
# C(OPERA)[T.British Airways]             -3.3521      1.345     -2.492      0.013      -5.989      -0.716
# C(OPERA)[T.Copa Air]                    -8.5700      0.595    -14.412      0.000      -9.736      -7.404
# C(OPERA)[T.Delta Air]                   -8.8232      1.053     -8.376      0.000     -10.888      -6.759
# C(OPERA)[T.Gol Trans]                    2.7265      0.767      3.554      0.000       1.223       4.230
# C(OPERA)[T.Grupo LATAM]                 -2.1496      0.425     -5.061      0.000      -2.982      -1.317
# C(OPERA)[T.Iberia]                      -6.1889      1.048     -5.903      0.000      -8.244      -4.134
# C(OPERA)[T.JetSmart SPA]                -3.3668      0.692     -4.866      0.000      -4.723      -2.011
# C(OPERA)[T.K.L.M.]                      -6.7166      1.229     -5.467      0.000      -9.124      -4.309
# C(OPERA)[T.Lacsa]                       -4.5689      1.955     -2.338      0.019      -8.400      -0.738
# C(OPERA)[T.Latin American Wings]        13.4420      0.610     22.019      0.000      12.245      14.639
# C(OPERA)[T.Oceanair Linhas Aereas]      -2.8944      1.173     -2.468      0.014      -5.193      -0.596
# C(OPERA)[T.Plus Ultra Lineas Aereas]    20.1394      2.650      7.600      0.000      14.946      25.333
# C(OPERA)[T.Qantas Airways]              14.8538      1.376     10.795      0.000      12.157      17.551
# C(OPERA)[T.Sky Airline]                 -3.0104      0.442     -6.805      0.000      -3.877      -2.143
# C(OPERA)[T.United Airlines]             -8.4533      1.084     -7.802      0.000     -10.577      -6.330
# ==============================================================================
# Omnibus:                    53938.445   Durbin-Watson:                   1.728
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1154400.057
# Skew:                           3.768   Prob(JB):                         0.00
# Kurtosis:                      21.692   Cond. No.                         46.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
anova = anova_lm(modelo)
anova
# Out:
#                df        sum_sq       mean_sq           F  PR(>F)
# C(OPERA)     22.0  8.262548e+05  37557.035371  111.906565     0.0
# Residual  68183.0  2.288294e+07    335.610653         NaN     NaN

# %%
formula='dif_min ~ C(TIPOVUELO)'
modelo = ols(formula = formula, data=df_e).fit()
modelo.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                dif_min   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     558.0
# Date:                Mon, 14 Mar 2022   Prob (F-statistic):          7.13e-123
# Time:                        04:21:20   Log-Likelihood:            -2.9604e+05
# No. Observations:               68206   AIC:                         5.921e+05
# Df Residuals:                   68204   BIC:                         5.921e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            11.9428      0.105    113.678      0.000      11.737      12.149
# C(TIPOVUELO)[T.N]    -3.3710      0.143    -23.622      0.000      -3.651      -3.091
# ==============================================================================
# Omnibus:                    54714.616   Durbin-Watson:                   1.683
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1184418.858
# Skew:                           3.848   Prob(JB):                         0.00
# Kurtosis:                      21.909   Cond. No.                         2.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
anova = anova_lm(modelo)
anova
# Out:
#                    df        sum_sq        mean_sq           F         PR(>F)
# C(TIPOVUELO)      1.0  1.924011e+05  192401.141421  558.006632  7.128469e-123
# Residual      68204.0  2.351679e+07     344.800815         NaN            NaN

# %% [markdown]
# # 4.
# # Entrena uno o varios modelos (usando el/los algoritmo(s) que prefieras) para estimar la probabilidad de atraso de un vuelo. Siéntete libre de generar variables adicionales y/o complementar con variables externas.

# %%
df_e
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O  Vlo-O  \
# 0     2017-01-01 23:30:00   226  SCEL  KMIA   AAL 2017-01-01 23:33:00    226
# 1     2017-01-02 23:30:00   226  SCEL  KMIA   AAL 2017-01-02 23:39:00    226
# 2     2017-01-03 23:30:00   226  SCEL  KMIA   AAL 2017-01-03 23:39:00    226
# 3     2017-01-04 23:30:00   226  SCEL  KMIA   AAL 2017-01-04 23:33:00    226
# 4     2017-01-05 23:30:00   226  SCEL  KMIA   AAL 2017-01-05 23:28:00    226
# ...                   ...   ...   ...   ...   ...                 ...    ...
# 68201 2017-12-22 14:55:00   400  SCEL  SPJC   JAT 2017-12-22 15:41:00  400.0
# 68202 2017-12-25 14:55:00   400  SCEL  SPJC   JAT 2017-12-25 15:11:00  400.0
# 68203 2017-12-27 14:55:00   400  SCEL  SPJC   JAT 2017-12-27 15:35:00  400.0
# 68204 2017-12-29 14:55:00   400  SCEL  SPJC   JAT 2017-12-29 15:08:00  400.0
# 68205 2017-12-31 14:55:00   400  SCEL  SPJC   JAT 2017-12-31 15:04:00  400.0
#
#       Ori-O  DesO EmpO  ...   AÑO     DIANOM  TIPOVUELO              OPERA  \
# 0      SCEL  KMIA  AAL  ...  2017    Domingo          I  American Airlines
# 1      SCEL  KMIA  AAL  ...  2017      Lunes          I  American Airlines
# 2      SCEL  KMIA  AAL  ...  2017     Martes          I  American Airlines
# 3      SCEL  KMIA  AAL  ...  2017  Miercoles          I  American Airlines
# 4      SCEL  KMIA  AAL  ...  2017     Jueves          I  American Airlines
# ...     ...   ...  ...  ...   ...        ...        ...                ...
# 68201  SCEL  SPJC  JAT  ...  2017    Viernes          I       JetSmart SPA
# 68202  SCEL  SPJC  JAT  ...  2017      Lunes          I       JetSmart SPA
# 68203  SCEL  SPJC  JAT  ...  2017  Miercoles          I       JetSmart SPA
# 68204  SCEL  SPJC  JAT  ...  2017    Viernes          I       JetSmart SPA
# 68205  SCEL  SPJC  JAT  ...  2017    Domingo          I       JetSmart SPA
#
#        SIGLAORI SIGLADES temporada_alta dif_min  atraso_15  periodo_dia
# 0      Santiago    Miami              1     3.0          0        noche
# 1      Santiago    Miami              1     9.0          0        noche
# 2      Santiago    Miami              1     9.0          0        noche
# 3      Santiago    Miami              1     3.0          0        noche
# 4      Santiago    Miami              1     0.0          0        noche
# ...         ...      ...            ...     ...        ...          ...
# 68201  Santiago     Lima              1    46.0          1        tarde
# 68202  Santiago     Lima              1    16.0          1        tarde
# 68203  Santiago     Lima              1    40.0          1        tarde
# 68204  Santiago     Lima              1    13.0          0        tarde
# 68205  Santiago     Lima              1     9.0          0        tarde
#
# [68206 rows x 22 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
df_e['DesO']=encoder.fit_transform(df_e.DesO.values)
df_e['EmpO']=encoder.fit_transform(df_e.EmpO.values)
df_e['DIANOM']=encoder.fit_transform(df_e.DIANOM.values)
df_e['TIPOVUELO']=encoder.fit_transform(df_e.TIPOVUELO.values)
df_e['OPERA']=encoder.fit_transform(df_e.OPERA.values)
df_e['periodo_dia']=encoder.fit_transform(df_e.periodo_dia.values)
df_e
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O  Vlo-O  \
# 0     2017-01-01 23:30:00   226  SCEL  KMIA   AAL 2017-01-01 23:33:00    226
# 1     2017-01-02 23:30:00   226  SCEL  KMIA   AAL 2017-01-02 23:39:00    226
# 2     2017-01-03 23:30:00   226  SCEL  KMIA   AAL 2017-01-03 23:39:00    226
# 3     2017-01-04 23:30:00   226  SCEL  KMIA   AAL 2017-01-04 23:33:00    226
# 4     2017-01-05 23:30:00   226  SCEL  KMIA   AAL 2017-01-05 23:28:00    226
# ...                   ...   ...   ...   ...   ...                 ...    ...
# 68201 2017-12-22 14:55:00   400  SCEL  SPJC   JAT 2017-12-22 15:41:00  400.0
# 68202 2017-12-25 14:55:00   400  SCEL  SPJC   JAT 2017-12-25 15:11:00  400.0
# 68203 2017-12-27 14:55:00   400  SCEL  SPJC   JAT 2017-12-27 15:35:00  400.0
# 68204 2017-12-29 14:55:00   400  SCEL  SPJC   JAT 2017-12-29 15:08:00  400.0
# 68205 2017-12-31 14:55:00   400  SCEL  SPJC   JAT 2017-12-31 15:04:00  400.0
#
#       Ori-O  DesO  EmpO  ...   AÑO  DIANOM  TIPOVUELO  OPERA  SIGLAORI  \
# 0      SCEL    10     2  ...  2017       0          0      5  Santiago
# 1      SCEL    10     2  ...  2017       2          0      5  Santiago
# 2      SCEL    10     2  ...  2017       3          0      5  Santiago
# 3      SCEL    10     2  ...  2017       4          0      5  Santiago
# 4      SCEL    10     2  ...  2017       1          0      5  Santiago
# ...     ...   ...   ...  ...   ...     ...        ...    ...       ...
# 68201  SCEL    57    16  ...  2017       6          0     14  Santiago
# 68202  SCEL    57    16  ...  2017       2          0     14  Santiago
# 68203  SCEL    57    16  ...  2017       4          0     14  Santiago
# 68204  SCEL    57    16  ...  2017       6          0     14  Santiago
# 68205  SCEL    57    16  ...  2017       0          0     14  Santiago
#
#        SIGLADES temporada_alta dif_min  atraso_15  periodo_dia
# 0         Miami              1     3.0          0            1
# 1         Miami              1     9.0          0            1
# 2         Miami              1     9.0          0            1
# 3         Miami              1     3.0          0            1
# 4         Miami              1     0.0          0            1
# ...         ...            ...     ...        ...          ...
# 68201      Lima              1    46.0          1            2
# 68202      Lima              1    16.0          1            2
# 68203      Lima              1    40.0          1            2
# 68204      Lima              1    13.0          0            2
# 68205      Lima              1     9.0          0            2
#
# [68206 rows x 22 columns]

# %% [markdown]
# # Regresion

# %% [raw]
# X=df_e[['DesO','EmpO','OPERA','TIPOVUELO','temporada_alta','DIANOM','MES','periodo_dia']]
# #X=df_e[['DesO','EmpO','temporada_alta','periodo_dia']]
# y=df_e['dif_min']
#
# from sklearn import decomposition
# pca=decomposition.PCA(n_components=3)
# #X=pca.fit_transform(X)
#
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)
#
# from sklearn.preprocessing import MinMaxScaler
# scaler=MinMaxScaler()
# scaler.fit(X_train)
# X_train=scaler.transform(X_train)
# X_test=scaler.transform(X_test)

# %% [markdown]
# ## Regresion Lineal

# %% [raw]
# from sklearn.linear_model import LinearRegression
# lr=LinearRegression()
# lr.fit(X_train,y_train)
# lr_predicciones=lr.predict(X_test)
#
# from sklearn.metrics import explained_variance_score, max_error, mean_absolute_error
# from sklearn.metrics import mean_squared_error, mean_squared_log_error
# from sklearn.metrics import median_absolute_error, r2_score, mean_poisson_deviance
# from sklearn.metrics import mean_absolute_percentage_error
#
# print('Puntuacion R2: ', r2_score(y_test,lr_predicciones))
# print('Precision Media: ',lr.score(X_train,y_train))
# print('Puntuación de la Varianza Explicada: ', explained_variance_score(y_test,lr_predicciones))
# print('Error Maximo: ', max_error(y_test,lr_predicciones))
# print('Error Absoluto Medio: ', mean_absolute_error(y_test,lr_predicciones))
# print('Error Absoluto Mediano: ', median_absolute_error(y_test,lr_predicciones))
# print('Error Cuadrado Medio: ', mean_squared_error(y_test,lr_predicciones))
# print('Error Log Cuadrado Medio: ', mean_squared_log_error(y_test,lr_predicciones))
# #print('Desviacion Poisson Media: ', mean_poisson_deviance(y_test,lr_predicciones))
# print('Error Absoluto Medio Porcentual: ', mean_absolute_percentage_error(y_test,lr_predicciones))

# %% [raw]
# residuos = []
# for i in range(len(y_test)):
#     residuos.append(np.array(y_test)[i]-lr_predicciones[i])
#
# from sklearn.preprocessing import StandardScaler
# scaler=StandardScaler()
# scaler.fit(np.array(residuos).reshape(-1, 1))
# residuosEstandarizados=scaler.transform(np.array(residuos).reshape(-1, 1))
#
# distr_norm = st.norm(loc=0,scale=1)
# x_val = X_test
# fig = plt.figure(figsize=(8,6))
#
# ax = fig.add_subplot(221)
# obs = [i for i in range(len(X_test))]
# ax.scatter(obs,residuosEstandarizados, color='green')
# ax.set_xlabel('Observaciones')
# ax.set_ylabel('Standard error')
#
# ax = fig.add_subplot(222)
# ax.scatter(lr_predicciones,residuosEstandarizados, color='brown')
# ax.set_xlabel('Mean response')
# ax.set_ylabel('Standart error')
#
# ax = fig.add_subplot(223)
# #st.probplot(residuosEstandarizados, plot=ax)
# ax.scatter(y_test,lr_predicciones, c='blue', marker='o',edgecolors='black')
# ax.set_xlabel('y_test')
# ax.set_ylabel('predicciones')
#
# ax = fig.add_subplot(224)
# ax.hist(residuosEstandarizados, bins = round(1+3.322*m.log10(len(y_test))))
# ax.plot(x_val, distr_norm.pdf(x_val))
# ax.set_xlabel('Standart error')
# ax.set_ylabel('Frecuency')
# ax.set_title('Histogram')
#
# plt.tight_layout()

# %% [raw]
# from sklearn.model_selection import GridSearchCV
# lr_grid={'fit_intercept': ['True', 'False'],
#     'normalize': ['True', 'False'],
#          'n_jobs':[-1,1,3,5,8],
#          'positive':['True','False']
#      }
# lr_red=GridSearchCV(LinearRegression(), lr_grid , cv = 5, refit= True, verbose= 3)
# lr_red.fit(X_train, y_train)
# lr_predicciones_red=lr_red.predict(X_test)
#
# print('Puntuacion R2: ', r2_score(y_test,lr_predicciones_red))
# print('Precision Media: ',lr_red.score(X_train,y_train))
# print('Puntuación de la Varianza Explicada: ', explained_variance_score(y_test,lr_predicciones_red))
# print('Error Maximo: ', max_error(y_test,lr_predicciones_red))
# print('Error Absoluto Medio: ', mean_absolute_error(y_test,lr_predicciones_red))
# print('Error Absoluto Mediano: ', median_absolute_error(y_test,lr_predicciones_red))
# print('Error Cuadrado Medio: ', mean_squared_error(y_test,lr_predicciones_red))
# print('Error Log Cuadrado Medio: ', mean_squared_log_error(y_test,lr_predicciones_red))
# #print('Desviacion Poisson Media: ', mean_poisson_deviance(y_test,lr_predicciones_red))
# print('Error Absoluto Medio Porcentual: ', mean_absolute_percentage_error(y_test,lr_predicciones_red))

# %% [raw]
# lr_red.best_estimator_

# %% [markdown]
# ## Arbol de Decision

# %% [raw]
# from sklearn.tree import DecisionTreeRegressor
# dt=DecisionTreeRegressor()
# dt.fit(X_train,y_train)
# dt_predicciones=dt.predict(X_test)

# %% [raw]
# print('Puntuación de la Varianza Explicada: ', explained_variance_score(y_test,dt_predicciones))
# print('Error Maximo: ', max_error(y_test,dt_predicciones))
# print('Error Absoluto Medio: ', mean_absolute_error(y_test,dt_predicciones))
# print('Error Absoluto Mediano: ', median_absolute_error(y_test,dt_predicciones))
# print('Error Cuadrado Medio: ', mean_squared_error(y_test,dt_predicciones))
# print('Error Log Cuadrado Medio: ', mean_squared_log_error(y_test,dt_predicciones))
# print('Puntuacion R2: ', r2_score(y_test,dt_predicciones))
# #print('Desviacion Poisson Media: ', mean_poisson_deviance(y_test,dt_predicciones))
# print('Error Absoluto Medio Porcentual: ', mean_absolute_percentage_error(y_test,dt_predicciones))

# %% [raw]
# dt_grid={'criterion':['mse','absolute_error','poisson'],
#          'splitter':['best', 'random'],
#          'max_depth':['None',5,10,50,100],
#          'min_samples_split':[1,2,5,7],
#          'min_samples_leaf':[1,2,5,7],
#          'max_features':[1,5,10,'auto','sqrt','log2'],
#          'random_state':['None',1,5,10,100]
#
#      }
# dt_red=GridSearchCV(DecisionTreeRegressor(), dt_grid , cv = 5, refit= True, verbose= 3)
# dt_red.fit(X_train, y_train)
# dt_predicciones_red=dt_red.predict(X_test)
#
# print('Puntuacion R2: ', r2_score(y_test,dt_predicciones_red))
# print('Precision Media: ',dt_red.score(X_train,y_train))
# print('Puntuación de la Varianza Explicada: ', explained_variance_score(y_test,dt_predicciones_red))
# print('Error Maximo: ', max_error(y_test,dt_predicciones_red))
# print('Error Absoluto Medio: ', mean_absolute_error(y_test,dt_predicciones_red))
# print('Error Absoluto Mediano: ', median_absolute_error(y_test,dt_predicciones_red))
# print('Error Cuadrado Medio: ', mean_squared_error(y_test,dt_predicciones_red))
# print('Error Log Cuadrado Medio: ', mean_squared_log_error(y_test,dt_predicciones_red))
# #print('Desviacion Poisson Media: ', mean_poisson_deviance(y_test,dt_predicciones_red))
# print('Error Absoluto Medio Porcentual: ', mean_absolute_percentage_error(y_test,dt_predicciones_red))

# %% [markdown]
# ## Bosque Aleatorio

# %% [raw]
# from sklearn.ensemble import RandomForestRegressor
# rf=RandomForestRegressor(n_estimators=300,min_samples_leaf=10,random_state=None,n_jobs=None,oob_score=False)
# rf.fit(X_train,y_train)
# rf_predicciones=rf.predict(X_test)

# %% [raw]
# print('Puntuación de la Varianza Explicada: ', explained_variance_score(y_test,rf_predicciones))
# print('Error Maximo: ', max_error(y_test,rf_predicciones))
# print('Error Absoluto Medio: ', mean_absolute_error(y_test,rf_predicciones))
# print('Error Absoluto Mediano: ', median_absolute_error(y_test,rf_predicciones))
# print('Error Cuadrado Medio: ', mean_squared_error(y_test,rf_predicciones))
# print('Error Log Cuadrado Medio: ', mean_squared_log_error(y_test,rf_predicciones))
# print('Puntuacion R2: ', r2_score(y_test,rf_predicciones))
# #print('Desviacion Poisson Media: ', mean_poisson_deviance(y_test,rf_predicciones))
# print('Error Absoluto Medio Porcentual: ', mean_absolute_percentage_error(y_test,rf_predicciones))

# %% [markdown]
# ## Red Neuronal

# %% [raw]
# from sklearn.neural_network import MLPRegressor
# #mlp=MLPRegressor(hidden_layer_sizes=(10,10,10),max_iter=100,alpha=0.0001,solver='adam',random_state=21,tol=0.000000001)
# mlp=MLPRegressor(hidden_layer_sizes=(10,5,10))
# mlp.fit(X_train,y_train)
# mlp_predicciones=mlp.predict(X_test)

# %% [raw]
# print('Puntuación de la Varianza Explicada: ', explained_variance_score(y_test,mlp_predicciones))
# print('Error Maximo: ', max_error(y_test,mlp_predicciones))
# print('Error Absoluto Medio: ', mean_absolute_error(y_test,mlp_predicciones))
# print('Error Absoluto Mediano: ', median_absolute_error(y_test,mlp_predicciones))
# print('Error Cuadrado Medio: ', mean_squared_error(y_test,mlp_predicciones))
# #print('Error Log Cuadrado Medio: ', mean_squared_log_error(y_test,mlp_predicciones))
# print('Puntuacion R2: ', r2_score(y_test,mlp_predicciones))
# #print('Desviacion Poisson Media: ', mean_poisson_deviance(y_test,mlp_predicciones))
# print('Error Absoluto Medio Porcentual: ', mean_absolute_percentage_error(y_test,mlp_predicciones))

# %% [markdown]
# # Clasificacion

# %%
X=df_e[['DesO','EmpO','OPERA','TIPOVUELO','temporada_alta','DIANOM','MES','periodo_dia']]
#X=df_e[['DesO','EmpO','temporada_alta','periodo_dia']]
y=df_e['atraso_15']

from sklearn import decomposition
pca=decomposition.PCA(n_components=3)
#X=pca.fit_transform(X)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)
X_train
# Out:
# array([[-1.43492353e+00, -1.55996993e+00, -8.75415693e-01, ...,
#          5.17418531e-01, -7.46293154e-01, -2.52204452e-03],
#        [-1.80608945e+00, -2.64613178e+00, -2.08952889e+00, ...,
#         -4.78053356e-01, -7.46293154e-01,  1.15529039e+00],
#        [-1.43492353e+00, -1.55996993e+00, -8.75415693e-01, ...,
#          1.01515447e+00,  6.73620145e-01, -2.52204452e-03],
#        ...,
#        [ 1.98206520e-01, -3.18642099e-01, -2.68359094e-01, ...,
#         -4.78053356e-01, -7.46293154e-01, -1.16033448e+00],
#        [-1.13799080e+00, -3.18642099e-01, -2.68359094e-01, ...,
#          1.51289042e+00,  3.89637485e-01, -1.16033448e+00],
#        [ 1.53440384e+00, -3.18642099e-01, -2.68359094e-01, ...,
#          1.96825876e-02,  9.57602805e-01, -2.52204452e-03]])

# %% [markdown]
# ## Regresion Logistica

# %%
from sklearn.linear_model import LogisticRegression
logr=LogisticRegression()
logr.fit(X_train,y_train)
logr_predicciones=logr.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test,logr_predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90     16633
#            1       0.00      0.00      0.00      3829
#
#     accuracy                           0.81     20462
#    macro avg       0.41      0.50      0.45     20462
# weighted avg       0.66      0.81      0.73     20462
# C:\Users\Roberto\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Roberto\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Roberto\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import confusion_matrix
logr_array=confusion_matrix(y_test,logr_predicciones)
df_logr_array=pd.DataFrame(logr_array)
sns.set(font_scale=1)
plt.show(sns.heatmap(df_logr_array,annot=True,annot_kws={'size':16},cmap='Reds'))

# %%
#Memoria: Casos positivos correctamente detectados/Casos positivos reales
#Precision: Casos positivos correctamente detectados/Casos positivos totales asignados por el modelo
#Puntuacion F1: (2*Memoria*Precision)/((Memoria+Precision)
from sklearn.metrics import recall_score, precision_score, f1_score
print('Memoria logr: ', recall_score(y_test,logr_predicciones))
print('Precision logr: ', precision_score(y_test,logr_predicciones))
print('Puntuacion F1 logr: ', f1_score(y_test,logr_predicciones))
# Out:
# Memoria logr:  0.0
# Precision logr:  0.0
# Puntuacion F1 logr:  0.0
# C:\Users\Roberto\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Curva ROC: Es un grafico que muestra la especificidad vs la memoria. Para su construccion se utilizan las probabilidades predecidas por nuestro modelo.
#Especificidad: Casos negativos correctamente detectados/Casos negativos reales.
from sklearn.metrics import roc_curve, roc_auc_score

logr_pbb_predicciones=logr.predict_proba(X_test)

memlogr, unomenosespeclogr, umbrallogr = roc_curve(y_test,logr_pbb_predicciones[:,1])
plt.title('Curva ROC Regresion Logistica')
plt.plot(memlogr, unomenosespeclogr)
plt.plot([0,1],[0,1],linestyle='--')
plt.xlim(0.0,1.0)
plt.ylim(0.0,1.0)
plt.xlabel('1-especificidad')
plt.ylabel('memoria')
plt.show()

# %%
print('Area por debajo de la curva ROC: ',roc_auc_score(y_test,logr_pbb_predicciones[:,1]))
# Out:
# Area por debajo de la curva ROC:  0.6167620018396942

# %% [markdown]
# ## Arbol de Decision

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(X_train,y_train)
dtc_predicciones=dtc.predict(X_test)

print(classification_report(y_test,dtc_predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88     16633
#            1       0.39      0.20      0.26      3829
#
#     accuracy                           0.79     20462
#    macro avg       0.61      0.56      0.57     20462
# weighted avg       0.75      0.79      0.76     20462

# %%
dtc_array=confusion_matrix(y_test,dtc_predicciones)
df_dtc_array=pd.DataFrame(dtc_array)
sns.set(font_scale=1)
plt.show(sns.heatmap(df_dtc_array,annot=True,annot_kws={'size':16},cmap='Reds'))

# %%
print('Memoria dtc: ', recall_score(y_test,dtc_predicciones))
print('Precision dtc: ', precision_score(y_test,dtc_predicciones))
print('Puntuacion F1 dtc: ', f1_score(y_test,dtc_predicciones))
# Out:
# Memoria dtc:  0.19535126664925567
# Precision dtc:  0.38556701030927837
# Puntuacion F1 dtc:  0.2593170393482406

# %%
dtc_pbb_predicciones=dtc.predict_proba(X_test)

memdtc, unomenosespecdtc, umbraldtc = roc_curve(y_test,dtc_pbb_predicciones[:,1])
plt.title('Curva ROC Arbol de Decision')
plt.plot(memdtc, unomenosespecdtc)
plt.plot([0,1],[0,1],linestyle='--')
plt.xlim(0.0,1.0)
plt.ylim(0.0,1.0)
plt.xlabel('1-especificidad')
plt.ylabel('memoria')
plt.show()

# %%
print('Area por debajo de la curva ROC: ',roc_auc_score(y_test,dtc_pbb_predicciones[:,1]))
# Out:
# Area por debajo de la curva ROC:  0.6004917868280398

# %% [markdown]
# ## Bosque Aleatorio

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(X_train,y_train)
rfc_predicciones=rfc.predict(X_test)

print(classification_report(y_test,rfc_predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87     16633
#            1       0.38      0.24      0.29      3829
#
#     accuracy                           0.79     20462
#    macro avg       0.61      0.57      0.58     20462
# weighted avg       0.75      0.79      0.76     20462

# %%
rfc_array=confusion_matrix(y_test,rfc_predicciones)
df_rfc_array=pd.DataFrame(rfc_array)
sns.set(font_scale=1)
plt.show(sns.heatmap(df_rfc_array,annot=True,annot_kws={'size':16},cmap='Reds'))

# %%
print('Memoria dtc: ', recall_score(y_test,rfc_predicciones))
print('Precision dtc: ', precision_score(y_test,rfc_predicciones))
print('Puntuacion F1 dtc: ', f1_score(y_test,rfc_predicciones))
# Out:
# Memoria dtc:  0.23504831548707233
# Precision dtc:  0.3818413237165889
# Puntuacion F1 dtc:  0.2909796314258002

# %%
rfc_pbb_predicciones=rfc.predict_proba(X_test)

memrfc, unomenosespecrfc, umbralrfc = roc_curve(y_test,rfc_pbb_predicciones[:,1])
plt.title('Curva ROC Bosque Aleatorio')
plt.plot(memrfc, unomenosespecrfc)
plt.plot([0,1],[0,1],linestyle='--')
plt.xlim(0.0,1.0)
plt.ylim(0.0,1.0)
plt.xlabel('1-especificidad')
plt.ylabel('memoria')
plt.show()

# %%
print('Area por debajo de la curva ROC: ',roc_auc_score(y_test,rfc_pbb_predicciones[:,1]))
# Out:
# Area por debajo de la curva ROC:  0.6429509206926536

# %% [markdown]
# ## Red Neuronal

# %%
from sklearn.neural_network import MLPClassifier
mlpc=MLPClassifier()
mlpc.fit(X_train,y_train)
mlpc_predicciones=mlpc.predict(X_test)

print(classification_report(y_test,mlpc_predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.90     16633
#            1       0.61      0.07      0.13      3829
#
#     accuracy                           0.82     20462
#    macro avg       0.72      0.53      0.51     20462
# weighted avg       0.78      0.82      0.75     20462

# %%
mlpc_array=confusion_matrix(y_test,mlpc_predicciones)
df_mlpc_array=pd.DataFrame(mlpc_array)
sns.set(font_scale=1)
plt.show(sns.heatmap(df_mlpc_array,annot=True,annot_kws={'size':16},cmap='Reds'))

# %%
print('Memoria dtc: ', recall_score(y_test,mlpc_predicciones))
print('Precision dtc: ', precision_score(y_test,mlpc_predicciones))
print('Puntuacion F1 dtc: ', f1_score(y_test,mlpc_predicciones))
# Out:
# Memoria dtc:  0.07286497780099242
# Precision dtc:  0.6131868131868132
# Puntuacion F1 dtc:  0.13025210084033612

# %%
mlpc_pbb_predicciones=mlpc.predict_proba(X_test)

memmlpc, unomenosespecmlpc, umbralmlpc = roc_curve(y_test,mlpc_pbb_predicciones[:,1])
plt.title('Curva ROC Bosque Aleatorio')
plt.plot(memmlpc, unomenosespecmlpc)
plt.plot([0,1],[0,1],linestyle='--')
plt.xlim(0.0,1.0)
plt.ylim(0.0,1.0)
plt.xlabel('1-especificidad')
plt.ylabel('memoria')
plt.show()

# %%
print('Area por debajo de la curva ROC: ',roc_auc_score(y_test,mlpc_pbb_predicciones[:,1]))
# Out:
# Area por debajo de la curva ROC:  0.6852895368885419

# %% [raw]
# mlpc_grid={'hidden_layer_sizes': [(5,10,5), (10,5,10),(100,100)],
#     'activation':['identity','logistic','tanh','relu'],
#          'alpha':[0.1,0.01,0.001,0.0001],
#          'batch_size':['auto',2,5,10,100],
#          'learning_rate':['constant','invscaling','adaptive'],
#         'validation_fraction':[0.05,0.1,0.5]
#      }
# mlpc_red=GridSearchCV(MLPClassifier(), mlpc_grid , cv = 5, refit= True, verbose= 3)
# mlpc_red.fit(X_train, y_train)
# mlpc_predicciones_red=mlpc_red.predict(X_test)
#
# print(classification_report(y_test,mlpc_predicciones_red))

# %% [raw]
# mlpc_array=confusion_matrix(y_test,mlpc_predicciones_red)
# df_mlpc_array=pd.DataFrame(mlpc_array)
# sns.set(font_scale=1)
# plt.show(sns.heatmap(df_mlpc_array,annot=True,annot_kws={'size':16},cmap='Reds'))
